# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import time
import random

from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class DecomNet(nn.Module):
    def __init__(self, channel=64, kernel_size=3):
        super(DecomNet, self).__init__()
        # Shallow feature extraction
        self.net1_conv0 = nn.Conv2d(4, channel, kernel_size * 3,
                                    padding=4, padding_mode='replicate')
        # Activated layers!
        self.net1_convs = nn.Sequential(nn.Conv2d(channel, channel, kernel_size,
                                                  padding=1, padding_mode='replicate'),
                                        nn.ReLU(),
                                        nn.Conv2d(channel, channel, kernel_size,
                                                  padding=1, padding_mode='replicate'),
                                        nn.ReLU(),
                                        nn.Conv2d(channel, channel, kernel_size,
                                                  padding=1, padding_mode='replicate'),
                                        nn.ReLU(),
                                        nn.Conv2d(channel, channel, kernel_size,
                                                  padding=1, padding_mode='replicate'),
                                        nn.ReLU(),
                                        nn.Conv2d(channel, channel, kernel_size,
                                                  padding=1, padding_mode='replicate'),
                                        nn.ReLU())
        # Final recon layer
        self.net1_recon = nn.Conv2d(channel, 4, kernel_size,
                                    padding=1, padding_mode='replicate')

    def forward(self, input_im):
        input_max= torch.max(input_im, dim=1, keepdim=True)[0]
        input_img= torch.cat((input_max, input_im), dim=1)
        feats0   = self.net1_conv0(input_img)
        featss   = self.net1_convs(feats0)
        outs     = self.net1_recon(featss)
        R        = torch.sigmoid(outs[:, 0:3, :, :])
        L        = torch.sigmoid(outs[:, 3:4, :, :])
        return R, L

class RelightNet(nn.Module):
    def __init__(self, channel=64, kernel_size=3):
        super(RelightNet, self).__init__()

        self.relu         = nn.ReLU()
        self.net2_conv0_1 = nn.Conv2d(4, channel, kernel_size,
                                      padding=1, padding_mode='replicate')

        self.net2_conv1_1 = nn.Conv2d(channel, channel, kernel_size, stride=2,
                                      padding=1, padding_mode='replicate')
        self.net2_conv1_2 = nn.Conv2d(channel, channel, kernel_size, stride=2,
                                      padding=1, padding_mode='replicate')
        self.net2_conv1_3 = nn.Conv2d(channel, channel, kernel_size, stride=2,
                                      padding=1, padding_mode='replicate')

        self.net2_deconv1_1= nn.Conv2d(channel*2, channel, kernel_size,
                                       padding=1, padding_mode='replicate')
        self.net2_deconv1_2= nn.Conv2d(channel*2, channel, kernel_size,
                                       padding=1, padding_mode='replicate')
        self.net2_deconv1_3= nn.Conv2d(channel*2, channel, kernel_size,
                                       padding=1, padding_mode='replicate')

        self.net2_fusion = nn.Conv2d(channel*3, channel, kernel_size=1,
                                     padding=1, padding_mode='replicate')
        self.net2_output = nn.Conv2d(channel, 1, kernel_size=3, padding=0)

    def forward(self, input_L, input_R):
        input_img = torch.cat((input_R, input_L), dim=1)
        out0      = self.net2_conv0_1(input_img)
        out1      = self.relu(self.net2_conv1_1(out0))
        out2      = self.relu(self.net2_conv1_2(out1))
        out3      = self.relu(self.net2_conv1_3(out2))

        out3_up   = F.interpolate(out3, size=(out2.size()[2], out2.size()[3]))
        deconv1   = self.relu(self.net2_deconv1_1(torch.cat((out3_up, out2), dim=1)))
        deconv1_up= F.interpolate(deconv1, size=(out1.size()[2], out1.size()[3]))
        deconv2   = self.relu(self.net2_deconv1_2(torch.cat((deconv1_up, out1), dim=1)))
        deconv2_up= F.interpolate(deconv2, size=(out0.size()[2], out0.size()[3]))
        deconv3   = self.relu(self.net2_deconv1_3(torch.cat((deconv2_up, out0), dim=1)))

        deconv1_rs= F.interpolate(deconv1, size=(input_R.size()[2], input_R.size()[3]))
        deconv2_rs= F.interpolate(deconv2, size=(input_R.size()[2], input_R.size()[3]))
        feats_all = torch.cat((deconv1_rs, deconv2_rs, deconv3), dim=1)
        feats_fus = self.net2_fusion(feats_all)
        output    = self.net2_output(feats_fus)
        return output


class RetinexNet(nn.Module):
    def __init__(self):
        super(RetinexNet, self).__init__()

        self.DecomNet  = DecomNet()
        self.RelightNet= RelightNet()

    def forward(self, input_low, input_high):
        # Forward DecompNet
        input_low = Variable(torch.FloatTensor(torch.from_numpy(input_low))).to(device)
        input_high= Variable(torch.FloatTensor(torch.from_numpy(input_high))).to(device)
        R_low, I_low   = self.DecomNet(input_low)
        R_high, I_high = self.DecomNet(input_high)

        # Forward RelightNet
        I_delta = self.RelightNet(I_low, R_low)

        # Other variables
        I_low_3  = torch.cat((I_low, I_low, I_low), dim=1)
        I_high_3 = torch.cat((I_high, I_high, I_high), dim=1)
        I_delta_3= torch.cat((I_delta, I_delta, I_delta), dim=1)

        # Compute losses
        self.recon_loss_low  = F.l1_loss(R_low * I_low_3,  input_low)
        self.recon_loss_high = F.l1_loss(R_high * I_high_3, input_high)
        self.recon_loss_mutal_low  = F.l1_loss(R_high * I_low_3, input_low)
        self.recon_loss_mutal_high = F.l1_loss(R_low * I_high_3, input_high)
        self.equal_R_loss = F.l1_loss(R_low,  R_high.detach())
        self.relight_loss = F.l1_loss(R_low * I_delta_3, input_high)

        self.Ismooth_loss_low   = self.smooth(I_low, R_low)
        self.Ismooth_loss_high  = self.smooth(I_high, R_high)
        self.Ismooth_loss_delta = self.smooth(I_delta, R_low)

        self.loss_Decom = self.recon_loss_low + \
                          self.recon_loss_high + \
                          0.001 * self.recon_loss_mutal_low + \
                          0.001 * self.recon_loss_mutal_high + \
                          0.1 * self.Ismooth_loss_low + \
                          0.1 * self.Ismooth_loss_high + \
                          0.01 * self.equal_R_loss
        self.loss_Relight = self.relight_loss + \
                            3 * self.Ismooth_loss_delta

        self.output_R_low   = R_low.detach().cpu()
        self.output_I_low   = I_low_3.detach().cpu()
        self.output_I_delta = I_delta_3.detach().cpu()
        self.output_S       = R_low.detach().cpu() * I_delta_3.detach().cpu()

    def gradient(self, input_tensor, direction):
        self.smooth_kernel_x = torch.FloatTensor([[0, 0], [-1, 1]]).view((1, 1, 2, 2)).to(device)
        self.smooth_kernel_y = torch.transpose(self.smooth_kernel_x, 2, 3)

        if direction == "x":
            kernel = self.smooth_kernel_x
        elif direction == "y":
            kernel = self.smooth_kernel_y
        grad_out = torch.abs(F.conv2d(input_tensor, kernel,
                                      stride=1, padding=1))
        return grad_out

    def ave_gradient(self, input_tensor, direction):
        return F.avg_pool2d(self.gradient(input_tensor, direction),
                            kernel_size=3, stride=1, padding=1)

    def smooth(self, input_I, input_R):
        input_R = 0.299*input_R[:, 0, :, :] + 0.587*input_R[:, 1, :, :] + 0.114*input_R[:, 2, :, :]
        input_R = torch.unsqueeze(input_R, dim=1)
        return torch.mean(self.gradient(input_I, "x") * torch.exp(-10 * self.ave_gradient(input_R, "x")) +
                          self.gradient(input_I, "y") * torch.exp(-10 * self.ave_gradient(input_R, "y")))

    def evaluate(self, epoch_num, eval_low_data_names, vis_dir, train_phase):
        print("Evaluating for phase %s / epoch %d..." % (train_phase, epoch_num))

        for idx in range(len(eval_low_data_names)):
            eval_low_img   = Image.open(eval_low_data_names[idx])
            eval_low_img   = np.array(eval_low_img, dtype="float32")/255.0
            eval_low_img   = np.transpose(eval_low_img, (2, 0, 1))
            input_low_eval = np.expand_dims(eval_low_img, axis=0)

            if train_phase == "Decom":
                self.forward(input_low_eval, input_low_eval)
                result_1 = self.output_R_low
                result_2 = self.output_I_low
                input    = np.squeeze(input_low_eval)
                result_1 = np.squeeze(result_1)
                result_2 = np.squeeze(result_2)
                cat_image= np.concatenate([input, result_1, result_2], axis=2)
            if train_phase == "Relight":
                self.forward(input_low_eval, input_low_eval)
                result_1 = self.output_R_low
                result_2 = self.output_I_low
                result_3 = self.output_I_delta
                result_4 = self.output_S
                input = np.squeeze(input_low_eval)
                result_1 = np.squeeze(result_1)
                result_2 = np.squeeze(result_2)
                result_3 = np.squeeze(result_3)
                result_4 = np.squeeze(result_4)
                cat_image= np.concatenate([input, result_1, result_2, result_3, result_4], axis=2)

            cat_image = np.transpose(cat_image, (1, 2, 0))
            # print(cat_image.shape)
            im = Image.fromarray(np.clip(cat_image * 255.0, 0, 255.0).astype('uint8'))
            filepath = os.path.join(vis_dir, 'eval_%s_%d_%d.png' %
                       (train_phase, idx + 1, epoch_num))
            im.save(filepath[:-4] + '.png')


    def save(self, iter_num, ckpt_dir):
        save_dir = ckpt_dir + '/' + self.train_phase + '/'
        save_name= save_dir + '/' + str(iter_num) + '.tar'
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        if self.train_phase == 'Decom':
            torch.save(self.DecomNet.state_dict(), save_name)
        elif self.train_phase == 'Relight':
            torch.save(self.RelightNet.state_dict(),save_name)

    def load(self, ckpt_dir):
        load_dir   = ckpt_dir + '/' + self.train_phase + '/'
        if os.path.exists(load_dir):
            load_ckpts = os.listdir(load_dir)
            load_ckpts.sort()
            load_ckpts = sorted(load_ckpts, key=len)
            if len(load_ckpts)>0:
                load_ckpt  = load_ckpts[-1]
                global_step= int(load_ckpt[:-4])
                ckpt_dict  = torch.load(load_dir + load_ckpt)
                if self.train_phase == 'Decom':
                    self.DecomNet.load_state_dict(ckpt_dict)
                elif self.train_phase == 'Relight':
                    self.RelightNet.load_state_dict(ckpt_dict)
                return True, global_step
            else:
                return False, 0
        else:
            return False, 0


    def train(self,
              train_low_data_names,
              train_high_data_names,
              eval_low_data_names,
              batch_size,
              patch_size, epoch,
              lr,
              vis_dir,
              ckpt_dir,
              eval_every_epoch,
              train_phase):
        assert len(train_low_data_names) == len(train_high_data_names)
        numBatch = len(train_low_data_names) // int(batch_size)

        # Create the optimizers
        self.train_op_Decom   = optim.Adam(self.DecomNet.parameters(),
                                           lr=lr[0], betas=(0.9, 0.999))
        self.train_op_Relight = optim.Adam(self.RelightNet.parameters(),
                                           lr=lr[0], betas=(0.9, 0.999))

        # Initialize a network if its checkpoint is available
        self.train_phase= train_phase
        load_model_status, global_step = self.load(ckpt_dir)
        if load_model_status:
            iter_num    = global_step
            start_epoch = global_step // numBatch
            start_step  = global_step % numBatch
            print("Model restore success!")
        else:
            iter_num    = 0
            start_epoch = 0
            start_step  = 0
            print("No pretrained model to restore!")

        print("Start training for phase %s, with start epoch %d start iter %d : " %
             (self.train_phase, start_epoch, iter_num))

        start_time = time.time()
        image_id   = 0
        for epoch in range(start_epoch, epoch):
            self.lr = lr[epoch]
            # Adjust learning rate
            for param_group in self.train_op_Decom.param_groups:
                param_group['lr'] = self.lr
            for param_group in self.train_op_Relight.param_groups:
                param_group['lr'] = self.lr
            for batch_id in range(start_step, numBatch):
                # Generate training data for a batch
                batch_input_low = np.zeros((batch_size, 3, patch_size, patch_size,), dtype="float32")
                batch_input_high= np.zeros((batch_size, 3, patch_size, patch_size,), dtype="float32")
                for patch_id in range(batch_size):
                    # Load images
                    train_low_img = Image.open(train_low_data_names[image_id])
                    train_low_img = np.array(train_low_img, dtype='float32')/255.0
                    train_high_img= Image.open(train_high_data_names[image_id])
                    train_high_img= np.array(train_high_img, dtype='float32')/255.0
                    # Take random crops
                    h, w, _        = train_low_img.shape
                    x = random.randint(0, h - patch_size)
                    y = random.randint(0, w - patch_size)
                    train_low_img = train_low_img[x: x + patch_size, y: y + patch_size, :]
                    train_high_img= train_high_img[x: x + patch_size, y: y + patch_size, :]
                    # Data augmentation
                    if random.random() < 0.5:
                        train_low_img = np.flipud(train_low_img)
                        train_high_img= np.flipud(train_high_img)
                    if random.random() < 0.5:
                        train_low_img = np.fliplr(train_low_img)
                        train_high_img= np.fliplr(train_high_img)
                    rot_type = random.randint(1, 4)
                    if random.random() < 0.5:
                        train_low_img = np.rot90(train_low_img, rot_type)
                        train_high_img= np.rot90(train_high_img, rot_type)
                    # Permute the images to tensor format
                    train_low_img = np.transpose(train_low_img, (2, 0, 1))
                    train_high_img= np.transpose(train_high_img, (2, 0, 1))
                    # Prepare the batch
                    batch_input_low[patch_id, :, :, :] = train_low_img
                    batch_input_high[patch_id, :, :, :]= train_high_img
                    self.input_low = batch_input_low
                    self.input_high= batch_input_high

                    image_id = (image_id + 1) % len(train_low_data_names)
                    if image_id == 0:
                        tmp = list(zip(train_low_data_names, train_high_data_names))
                        random.shuffle(list(tmp))
                        train_low_data_names, train_high_data_names = zip(*tmp)


                # Feed-Forward to the network and obtain loss
                self.forward(self.input_low,  self.input_high)
                if self.train_phase == "Decom":
                    self.train_op_Decom.zero_grad()
                    self.loss_Decom.backward()
                    self.train_op_Decom.step()
                    loss = self.loss_Decom.item()
                elif self.train_phase == "Relight":
                    self.train_op_Relight.zero_grad()
                    self.loss_Relight.backward()
                    self.train_op_Relight.step()
                    loss = self.loss_Relight.item()

                print("%s Epoch: [%2d] [%4d/%4d] time: %4.4f, loss: %.6f" \
                      % (train_phase, epoch + 1, batch_id + 1, numBatch, time.time() - start_time, loss))
                iter_num += 1

            # Evaluate the model and save a checkpoint file for it
            if (epoch + 1) % eval_every_epoch == 0:
                self.evaluate(epoch + 1, eval_low_data_names,
                              vis_dir=vis_dir, train_phase=train_phase)
                self.save(iter_num, ckpt_dir)

        print("Finished training for phase %s." % train_phase)


    def predict(self,
                test_low_data_names,
                res_dir,
                ckpt_dir):

        # Load the network with a pre-trained checkpoint
        self.train_phase= 'Decom'
        load_model_status, _ = self.load(ckpt_dir)
        if load_model_status:
            print(self.train_phase, "  : Model restore success!")
        else:
            print("No pretrained model to restore!")
            raise Exception
        self.train_phase= 'Relight'
        load_model_status, _ = self.load(ckpt_dir)
        if load_model_status:
             print(self.train_phase, ": Model restore success!")
        else:
            print("No pretrained model to restore!")
            raise Exception

        # Set this switch to True to also save the reflectance and shading maps
        save_R_L = False

        # Predict for the test images
        for idx in range(len(test_low_data_names)):
            test_img_path  = test_low_data_names[idx]
            test_img_name  = test_img_path.split('/')[-1]
            print('Processing ', test_img_name)
            test_low_img   = Image.open(test_img_path)
            test_low_img   = np.array(test_low_img, dtype="float32")/255.0
            test_low_img   = np.transpose(test_low_img, (2, 0, 1))
            input_low_test = np.expand_dims(test_low_img, axis=0)

            self.forward(input_low_test, input_low_test)
            result_1 = self.output_R_low
            result_2 = self.output_I_low
            result_3 = self.output_I_delta
            result_4 = self.output_S
            input = np.squeeze(input_low_test)
            result_1 = np.squeeze(result_1)
            result_2 = np.squeeze(result_2)
            result_3 = np.squeeze(result_3)
            result_4 = np.squeeze(result_4)
            if save_R_L:
                cat_image= np.concatenate([input, result_1, result_2, result_3, result_4], axis=2)
            else:
                cat_image= np.concatenate([input, result_4], axis=2)

            cat_image = np.transpose(cat_image, (1, 2, 0))
            # print(cat_image.shape)
            im = Image.fromarray(np.clip(cat_image * 255.0, 0, 255.0).astype('uint8'))
            filepath = res_dir + '/' + test_img_name
            actual_name=test_img_name.split('\\')[-1]
            im.save('/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/eval/enhanced/'+actual_name)

# %%
# Train

import os
import argparse
from glob import glob
import numpy as np

data_dir = '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/train'
ckpt_dir = '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/checkpoints'
vis_dir = ckpt_dir + '/visuals/'

# Create directories for saving the checkpoints and visuals
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
if not os.path.exists(vis_dir):
    os.makedirs(vis_dir)

# Setup CUDA environment


def train(model):
    epochs = 100
    batch_size = 16
    patch_size = 96
    lr = 0.001
    data_dir = '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/train'
    ckpt_dir = '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/checkpoints'
    vis_dir = ckpt_dir + '/visuals/'

    if not os.path.exists(ckpt_dir):
        os.makedirs(ckpt_dir)
    if not os.path.exists(vis_dir):
        os.makedirs(vis_dir)

    lr = lr * np.ones([epochs])
    lr[20:] = lr[0] / 10.0

    train_low_data_names = glob(data_dir + '/low/*.png')
    train_low_data_names.sort()
    train_high_data_names= glob(data_dir + '/high/*.png')
    train_high_data_names.sort()
    eval_low_data_names  = glob(data_dir + '/eval/low/*.*')
    eval_low_data_names.sort()

    assert len(train_low_data_names) == len(train_high_data_names)
    print('Number of training data: %d' % len(train_low_data_names))

    model.train(train_low_data_names,
                train_high_data_names,
                eval_low_data_names,
                batch_size=batch_size,
                patch_size=patch_size,
                epoch=epochs,
                lr=lr,
                vis_dir=vis_dir,
                ckpt_dir=ckpt_dir,
                eval_every_epoch=10,
                train_phase="Decom")

    # Save the Decom model's state
    torch.save(model.state_dict(), '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/checkpoints/decom.pth')

    model.train(train_low_data_names,
                train_high_data_names,
                eval_low_data_names,
                batch_size=batch_size,
                patch_size=patch_size,
                epoch=epochs,
                lr=lr,
                vis_dir=vis_dir,
                ckpt_dir=ckpt_dir,
                eval_every_epoch=10,
                train_phase="Relight")

    # Save the Relight model's state
    torch.save(model.state_dict(), '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/checkpoints/relight.pth')


# Create the model
model = RetinexNet().to(device)

# Train the model
print("CUDA Available: ", torch.cuda.is_available())
train(model)
# Out:
# CUDA Available:  True
# Number of training data: 485
# Model restore success!
# Start training for phase Decom, with start epoch 40 start iter 1200 :
# Decom Epoch: [41] [   1/  30] time: 1.8823, loss: 0.031096
# Decom Epoch: [41] [   2/  30] time: 2.3623, loss: 0.058755
# Decom Epoch: [41] [   3/  30] time: 2.8462, loss: 0.036819
# Decom Epoch: [41] [   4/  30] time: 3.2991, loss: 0.036278
# Decom Epoch: [41] [   5/  30] time: 3.7662, loss: 0.049514
# Decom Epoch: [41] [   6/  30] time: 4.2159, loss: 0.042496
# Decom Epoch: [41] [   7/  30] time: 4.6776, loss: 0.038259
# Decom Epoch: [41] [   8/  30] time: 5.1558, loss: 0.032252
# Decom Epoch: [41] [   9/  30] time: 5.6195, loss: 0.049727
# Decom Epoch: [41] [  10/  30] time: 6.0981, loss: 0.044734
# Decom Epoch: [41] [  11/  30] time: 6.5594, loss: 0.050619
# Decom Epoch: [41] [  12/  30] time: 7.0373, loss: 0.052969
# Decom Epoch: [41] [  13/  30] time: 7.5131, loss: 0.061880
# Decom Epoch: [41] [  14/  30] time: 8.0073, loss: 0.040296
# Decom Epoch: [41] [  15/  30] time: 8.4904, loss: 0.045603
# Decom Epoch: [41] [  16/  30] time: 9.0926, loss: 0.036147
# Decom Epoch: [41] [  17/  30] time: 9.6561, loss: 0.043144
# Decom Epoch: [41] [  18/  30] time: 10.2186, loss: 0.035397
# Decom Epoch: [41] [  19/  30] time: 10.7985, loss: 0.030294
# Decom Epoch: [41] [  20/  30] time: 11.3854, loss: 0.037721
# Decom Epoch: [41] [  21/  30] time: 11.9727, loss: 0.043050
# Decom Epoch: [41] [  22/  30] time: 12.4461, loss: 0.033337
# Decom Epoch: [41] [  23/  30] time: 12.9487, loss: 0.059116
# Decom Epoch: [41] [  24/  30] time: 13.4266, loss: 0.039509
# Decom Epoch: [41] [  25/  30] time: 13.9146, loss: 0.038693
# Decom Epoch: [41] [  26/  30] time: 14.4000, loss: 0.049048
# Decom Epoch: [41] [  27/  30] time: 14.8882, loss: 0.039542
# Decom Epoch: [41] [  28/  30] time: 15.3514, loss: 0.040053
# Decom Epoch: [41] [  29/  30] time: 15.8406, loss: 0.050419
# Decom Epoch: [41] [  30/  30] time: 16.3418, loss: 0.029785
# Decom Epoch: [42] [   1/  30] time: 16.8319, loss: 0.032980
# Decom Epoch: [42] [   2/  30] time: 17.3059, loss: 0.027571
# Decom Epoch: [42] [   3/  30] time: 17.7924, loss: 0.028891
# Decom Epoch: [42] [   4/  30] time: 18.2711, loss: 0.029675
# Decom Epoch: [42] [   5/  30] time: 18.7396, loss: 0.030252
# Decom Epoch: [42] [   6/  30] time: 19.2346, loss: 0.031886
# Decom Epoch: [42] [   7/  30] time: 19.7015, loss: 0.031603
# Decom Epoch: [42] [   8/  30] time: 20.2037, loss: 0.030450
# Decom Epoch: [42] [   9/  30] time: 20.6811, loss: 0.031063
# Decom Epoch: [42] [  10/  30] time: 21.1788, loss: 0.043282
# Decom Epoch: [42] [  11/  30] time: 21.6529, loss: 0.043013
# Decom Epoch: [42] [  12/  30] time: 22.2026, loss: 0.044384
# Decom Epoch: [42] [  13/  30] time: 22.7615, loss: 0.045831
# Decom Epoch: [42] [  14/  30] time: 23.3355, loss: 0.048816
# Decom Epoch: [42] [  15/  30] time: 23.8942, loss: 0.038155
# Decom Epoch: [42] [  16/  30] time: 24.4725, loss: 0.030952
# Decom Epoch: [42] [  17/  30] time: 25.0576, loss: 0.049484
# Decom Epoch: [42] [  18/  30] time: 25.6217, loss: 0.038068
# Decom Epoch: [42] [  19/  30] time: 26.0988, loss: 0.038355
# Decom Epoch: [42] [  20/  30] time: 26.5832, loss: 0.030706
# Decom Epoch: [42] [  21/  30] time: 27.0708, loss: 0.032733
# Decom Epoch: [42] [  22/  30] time: 27.5491, loss: 0.046125
# Decom Epoch: [42] [  23/  30] time: 28.0382, loss: 0.049190
# Decom Epoch: [42] [  24/  30] time: 28.5141, loss: 0.042887
# Decom Epoch: [42] [  25/  30] time: 28.9933, loss: 0.037720
# Decom Epoch: [42] [  26/  30] time: 29.4801, loss: 0.054532
# Decom Epoch: [42] [  27/  30] time: 29.9606, loss: 0.035332
# Decom Epoch: [42] [  28/  30] time: 30.4257, loss: 0.039073
# Decom Epoch: [42] [  29/  30] time: 30.9134, loss: 0.042704
# Decom Epoch: [42] [  30/  30] time: 31.3988, loss: 0.036781
# Decom Epoch: [43] [   1/  30] time: 31.8838, loss: 0.033225
# Decom Epoch: [43] [   2/  30] time: 32.3494, loss: 0.030842
# Decom Epoch: [43] [   3/  30] time: 32.8165, loss: 0.029976
# Decom Epoch: [43] [   4/  30] time: 33.2980, loss: 0.030968
# Decom Epoch: [43] [   5/  30] time: 33.7663, loss: 0.027109
# Decom Epoch: [43] [   6/  30] time: 34.2397, loss: 0.024654
# Decom Epoch: [43] [   7/  30] time: 34.7058, loss: 0.035727
# Decom Epoch: [43] [   8/  30] time: 35.1970, loss: 0.034630
# Decom Epoch: [43] [   9/  30] time: 35.7239, loss: 0.031099
# Decom Epoch: [43] [  10/  30] time: 36.2865, loss: 0.045038
# Decom Epoch: [43] [  11/  30] time: 36.8444, loss: 0.043198
# Decom Epoch: [43] [  12/  30] time: 37.4100, loss: 0.039666
# Decom Epoch: [43] [  13/  30] time: 37.9782, loss: 0.060056
# Decom Epoch: [43] [  14/  30] time: 38.5483, loss: 0.038875
# Decom Epoch: [43] [  15/  30] time: 39.1123, loss: 0.043063
# Decom Epoch: [43] [  16/  30] time: 39.5998, loss: 0.031347
# Decom Epoch: [43] [  17/  30] time: 40.1051, loss: 0.044578
# Decom Epoch: [43] [  18/  30] time: 40.5780, loss: 0.029599
# Decom Epoch: [43] [  19/  30] time: 41.0635, loss: 0.027028
# Decom Epoch: [43] [  20/  30] time: 41.5403, loss: 0.038112
# Decom Epoch: [43] [  21/  30] time: 42.0359, loss: 0.035074
# Decom Epoch: [43] [  22/  30] time: 42.4951, loss: 0.042079
# Decom Epoch: [43] [  23/  30] time: 42.9945, loss: 0.037565
# Decom Epoch: [43] [  24/  30] time: 43.4792, loss: 0.046285
# Decom Epoch: [43] [  25/  30] time: 43.9718, loss: 0.032894
# Decom Epoch: [43] [  26/  30] time: 44.4498, loss: 0.041705
# Decom Epoch: [43] [  27/  30] time: 44.9205, loss: 0.040538
# Decom Epoch: [43] [  28/  30] time: 45.4132, loss: 0.032534
# Decom Epoch: [43] [  29/  30] time: 45.8865, loss: 0.046295
# Decom Epoch: [43] [  30/  30] time: 46.3909, loss: 0.047250
# Decom Epoch: [44] [   1/  30] time: 46.8852, loss: 0.036225
# Decom Epoch: [44] [   2/  30] time: 47.3724, loss: 0.033625
# Decom Epoch: [44] [   3/  30] time: 47.8425, loss: 0.024765
# Decom Epoch: [44] [   4/  30] time: 48.3357, loss: 0.026204
# Decom Epoch: [44] [   5/  30] time: 48.7947, loss: 0.027454
# Decom Epoch: [44] [   6/  30] time: 49.3769, loss: 0.030910
# Decom Epoch: [44] [   7/  30] time: 49.9231, loss: 0.034753
# Decom Epoch: [44] [   8/  30] time: 50.4898, loss: 0.033139
# Decom Epoch: [44] [   9/  30] time: 51.0304, loss: 0.024725
# Decom Epoch: [44] [  10/  30] time: 51.6050, loss: 0.045514
# Decom Epoch: [44] [  11/  30] time: 52.1973, loss: 0.042344
# Decom Epoch: [44] [  12/  30] time: 52.7054, loss: 0.048040
# Decom Epoch: [44] [  13/  30] time: 53.2015, loss: 0.036081
# Decom Epoch: [44] [  14/  30] time: 53.6823, loss: 0.047870
# Decom Epoch: [44] [  15/  30] time: 54.1759, loss: 0.052397
# Decom Epoch: [44] [  16/  30] time: 54.6485, loss: 0.037676
# Decom Epoch: [44] [  17/  30] time: 55.1520, loss: 0.031391
# Decom Epoch: [44] [  18/  30] time: 55.6415, loss: 0.035144
# Decom Epoch: [44] [  19/  30] time: 56.1391, loss: 0.026315
# Decom Epoch: [44] [  20/  30] time: 56.6265, loss: 0.041767
# Decom Epoch: [44] [  21/  30] time: 57.1138, loss: 0.042594
# Decom Epoch: [44] [  22/  30] time: 57.5918, loss: 0.036010
# Decom Epoch: [44] [  23/  30] time: 58.0552, loss: 0.031904
# Decom Epoch: [44] [  24/  30] time: 58.5565, loss: 0.062428
# Decom Epoch: [44] [  25/  30] time: 59.0071, loss: 0.034775
# Decom Epoch: [44] [  26/  30] time: 59.4920, loss: 0.039205
# Decom Epoch: [44] [  27/  30] time: 59.9573, loss: 0.049908
# Decom Epoch: [44] [  28/  30] time: 60.4358, loss: 0.036485
# Decom Epoch: [44] [  29/  30] time: 60.9019, loss: 0.041742
# Decom Epoch: [44] [  30/  30] time: 61.3835, loss: 0.045393
# Decom Epoch: [45] [   1/  30] time: 61.8425, loss: 0.034240
# Decom Epoch: [45] [   2/  30] time: 62.3326, loss: 0.033426
# Decom Epoch: [45] [   3/  30] time: 62.8841, loss: 0.027023
# Decom Epoch: [45] [   4/  30] time: 63.4397, loss: 0.028978
# Decom Epoch: [45] [   5/  30] time: 63.9985, loss: 0.029212
# Decom Epoch: [45] [   6/  30] time: 64.5312, loss: 0.026790
# Decom Epoch: [45] [   7/  30] time: 65.0972, loss: 0.037283
# Decom Epoch: [45] [   8/  30] time: 65.6566, loss: 0.032517
# Decom Epoch: [45] [   9/  30] time: 66.1761, loss: 0.033785
# Decom Epoch: [45] [  10/  30] time: 66.6411, loss: 0.035385
# Decom Epoch: [45] [  11/  30] time: 67.1173, loss: 0.040251
# Decom Epoch: [45] [  12/  30] time: 67.5771, loss: 0.043464
# Decom Epoch: [45] [  13/  30] time: 68.0625, loss: 0.039796
# Decom Epoch: [45] [  14/  30] time: 68.5384, loss: 0.063958
# Decom Epoch: [45] [  15/  30] time: 69.0257, loss: 0.045913
# Decom Epoch: [45] [  16/  30] time: 69.4988, loss: 0.037585
# Decom Epoch: [45] [  17/  30] time: 69.9765, loss: 0.029523
# Decom Epoch: [45] [  18/  30] time: 70.4618, loss: 0.050559
# Decom Epoch: [45] [  19/  30] time: 70.9548, loss: 0.026142
# Decom Epoch: [45] [  20/  30] time: 71.4505, loss: 0.034918
# Decom Epoch: [45] [  21/  30] time: 71.9350, loss: 0.035414
# Decom Epoch: [45] [  22/  30] time: 72.4304, loss: 0.031011
# Decom Epoch: [45] [  23/  30] time: 72.9179, loss: 0.044173
# Decom Epoch: [45] [  24/  30] time: 73.4169, loss: 0.044052
# Decom Epoch: [45] [  25/  30] time: 73.8994, loss: 0.043382
# Decom Epoch: [45] [  26/  30] time: 74.3855, loss: 0.031906
# Decom Epoch: [45] [  27/  30] time: 74.8784, loss: 0.046304
# Decom Epoch: [45] [  28/  30] time: 75.3733, loss: 0.029049
# Decom Epoch: [45] [  29/  30] time: 75.8473, loss: 0.038314
# Decom Epoch: [45] [  30/  30] time: 76.4212, loss: 0.050313
# Decom Epoch: [46] [   1/  30] time: 77.0408, loss: 0.033825
# Decom Epoch: [46] [   2/  30] time: 77.6160, loss: 0.028236
# Decom Epoch: [46] [   3/  30] time: 78.2038, loss: 0.026020
# Decom Epoch: [46] [   4/  30] time: 78.7753, loss: 0.028994
# Decom Epoch: [46] [   5/  30] time: 79.3695, loss: 0.027701
# Decom Epoch: [46] [   6/  30] time: 79.8361, loss: 0.024210
# Decom Epoch: [46] [   7/  30] time: 80.3323, loss: 0.032221
# Decom Epoch: [46] [   8/  30] time: 80.8048, loss: 0.035494
# Decom Epoch: [46] [   9/  30] time: 81.3043, loss: 0.033658
# Decom Epoch: [46] [  10/  30] time: 81.7877, loss: 0.029198
# Decom Epoch: [46] [  11/  30] time: 82.2906, loss: 0.043769
# Decom Epoch: [46] [  12/  30] time: 82.7687, loss: 0.041445
# Decom Epoch: [46] [  13/  30] time: 83.2460, loss: 0.041820
# Decom Epoch: [46] [  14/  30] time: 83.7499, loss: 0.046652
# Decom Epoch: [46] [  15/  30] time: 84.2351, loss: 0.035265
# Decom Epoch: [46] [  16/  30] time: 84.7359, loss: 0.036993
# Decom Epoch: [46] [  17/  30] time: 85.2081, loss: 0.033604
# Decom Epoch: [46] [  18/  30] time: 85.7067, loss: 0.046308
# Decom Epoch: [46] [  19/  30] time: 86.1856, loss: 0.035183
# Decom Epoch: [46] [  20/  30] time: 86.6767, loss: 0.028632
# Decom Epoch: [46] [  21/  30] time: 87.1648, loss: 0.033405
# Decom Epoch: [46] [  22/  30] time: 87.6605, loss: 0.045807
# Decom Epoch: [46] [  23/  30] time: 88.1394, loss: 0.036787
# Decom Epoch: [46] [  24/  30] time: 88.6302, loss: 0.045990
# Decom Epoch: [46] [  25/  30] time: 89.0996, loss: 0.045736
# Decom Epoch: [46] [  26/  30] time: 89.5994, loss: 0.036703
# Decom Epoch: [46] [  27/  30] time: 90.1859, loss: 0.038395
# Decom Epoch: [46] [  28/  30] time: 90.7598, loss: 0.041887
# Decom Epoch: [46] [  29/  30] time: 91.3356, loss: 0.040359
# Decom Epoch: [46] [  30/  30] time: 91.9113, loss: 0.037025
# Decom Epoch: [47] [   1/  30] time: 92.5107, loss: 0.043405
# Decom Epoch: [47] [   2/  30] time: 93.0680, loss: 0.025845
# Decom Epoch: [47] [   3/  30] time: 93.5531, loss: 0.032697
# Decom Epoch: [47] [   4/  30] time: 94.0117, loss: 0.030665
# Decom Epoch: [47] [   5/  30] time: 94.4943, loss: 0.029575
# Decom Epoch: [47] [   6/  30] time: 94.9646, loss: 0.027166
# Decom Epoch: [47] [   7/  30] time: 95.4256, loss: 0.025516
# Decom Epoch: [47] [   8/  30] time: 95.9087, loss: 0.033987
# Decom Epoch: [47] [   9/  30] time: 96.3708, loss: 0.031282
# Decom Epoch: [47] [  10/  30] time: 96.8705, loss: 0.028813
# Decom Epoch: [47] [  11/  30] time: 97.3361, loss: 0.035813
# Decom Epoch: [47] [  12/  30] time: 97.8337, loss: 0.035638
# Decom Epoch: [47] [  13/  30] time: 98.2973, loss: 0.046541
# Decom Epoch: [47] [  14/  30] time: 98.7968, loss: 0.048169
# Decom Epoch: [47] [  15/  30] time: 99.2765, loss: 0.043660
# Decom Epoch: [47] [  16/  30] time: 99.7758, loss: 0.051211
# Decom Epoch: [47] [  17/  30] time: 100.2441, loss: 0.037224
# Decom Epoch: [47] [  18/  30] time: 100.7369, loss: 0.038959
# Decom Epoch: [47] [  19/  30] time: 101.2074, loss: 0.034800
# Decom Epoch: [47] [  20/  30] time: 101.6732, loss: 0.033441
# Decom Epoch: [47] [  21/  30] time: 102.1554, loss: 0.032835
# Decom Epoch: [47] [  22/  30] time: 102.6185, loss: 0.032185
# Decom Epoch: [47] [  23/  30] time: 103.1014, loss: 0.040125
# Decom Epoch: [47] [  24/  30] time: 103.6682, loss: 0.044868
# Decom Epoch: [47] [  25/  30] time: 104.2569, loss: 0.055690
# Decom Epoch: [47] [  26/  30] time: 104.8125, loss: 0.035522
# Decom Epoch: [47] [  27/  30] time: 105.3938, loss: 0.036351
# Decom Epoch: [47] [  28/  30] time: 105.9646, loss: 0.050880
# Decom Epoch: [47] [  29/  30] time: 106.5449, loss: 0.043140
# Decom Epoch: [47] [  30/  30] time: 107.0129, loss: 0.040402
# Decom Epoch: [48] [   1/  30] time: 107.5109, loss: 0.047245
# Decom Epoch: [48] [   2/  30] time: 107.9850, loss: 0.027856
# Decom Epoch: [48] [   3/  30] time: 108.4543, loss: 0.025457
# Decom Epoch: [48] [   4/  30] time: 108.9421, loss: 0.023301
# Decom Epoch: [48] [   5/  30] time: 109.4226, loss: 0.022755
# Decom Epoch: [48] [   6/  30] time: 109.9104, loss: 0.028353
# Decom Epoch: [48] [   7/  30] time: 110.3683, loss: 0.026520
# Decom Epoch: [48] [   8/  30] time: 110.8425, loss: 0.030520
# Decom Epoch: [48] [   9/  30] time: 111.3003, loss: 0.028985
# Decom Epoch: [48] [  10/  30] time: 111.7776, loss: 0.033803
# Decom Epoch: [48] [  11/  30] time: 112.2509, loss: 0.029704
# Decom Epoch: [48] [  12/  30] time: 112.7354, loss: 0.035655
# Decom Epoch: [48] [  13/  30] time: 113.2017, loss: 0.037457
# Decom Epoch: [48] [  14/  30] time: 113.6727, loss: 0.029126
# Decom Epoch: [48] [  15/  30] time: 114.1639, loss: 0.053474
# Decom Epoch: [48] [  16/  30] time: 114.6303, loss: 0.036130
# Decom Epoch: [48] [  17/  30] time: 115.1284, loss: 0.031714
# Decom Epoch: [48] [  18/  30] time: 115.6139, loss: 0.027210
# Decom Epoch: [48] [  19/  30] time: 116.1026, loss: 0.042471
# Decom Epoch: [48] [  20/  30] time: 116.5808, loss: 0.033762
# Decom Epoch: [48] [  21/  30] time: 117.1635, loss: 0.032565
# Decom Epoch: [48] [  22/  30] time: 117.7174, loss: 0.033949
# Decom Epoch: [48] [  23/  30] time: 118.2870, loss: 0.030449
# Decom Epoch: [48] [  24/  30] time: 118.8376, loss: 0.045641
# Decom Epoch: [48] [  25/  30] time: 119.4380, loss: 0.055554
# Decom Epoch: [48] [  26/  30] time: 120.0145, loss: 0.037884
# Decom Epoch: [48] [  27/  30] time: 120.5106, loss: 0.032602
# Decom Epoch: [48] [  28/  30] time: 120.9837, loss: 0.040896
# Decom Epoch: [48] [  29/  30] time: 121.4517, loss: 0.040516
# Decom Epoch: [48] [  30/  30] time: 121.9267, loss: 0.037200
# Decom Epoch: [49] [   1/  30] time: 122.4075, loss: 0.043916
# Decom Epoch: [49] [   2/  30] time: 122.9010, loss: 0.028473
# Decom Epoch: [49] [   3/  30] time: 123.3631, loss: 0.031324
# Decom Epoch: [49] [   4/  30] time: 123.8429, loss: 0.025339
# Decom Epoch: [49] [   5/  30] time: 124.2977, loss: 0.022660
# Decom Epoch: [49] [   6/  30] time: 124.7772, loss: 0.028541
# Decom Epoch: [49] [   7/  30] time: 125.2494, loss: 0.026658
# Decom Epoch: [49] [   8/  30] time: 125.7487, loss: 0.031929
# Decom Epoch: [49] [   9/  30] time: 126.2164, loss: 0.039062
# Decom Epoch: [49] [  10/  30] time: 126.7123, loss: 0.034507
# Decom Epoch: [49] [  11/  30] time: 127.1800, loss: 0.026072
# Decom Epoch: [49] [  12/  30] time: 127.6576, loss: 0.042170
# Decom Epoch: [49] [  13/  30] time: 128.1286, loss: 0.045013
# Decom Epoch: [49] [  14/  30] time: 128.6016, loss: 0.039436
# Decom Epoch: [49] [  15/  30] time: 129.0829, loss: 0.043894
# Decom Epoch: [49] [  16/  30] time: 129.5454, loss: 0.054009
# Decom Epoch: [49] [  17/  30] time: 130.0587, loss: 0.033947
# Decom Epoch: [49] [  18/  30] time: 130.6179, loss: 0.026520
# Decom Epoch: [49] [  19/  30] time: 131.2094, loss: 0.038618
# Decom Epoch: [49] [  20/  30] time: 131.7522, loss: 0.028545
# Decom Epoch: [49] [  21/  30] time: 132.3276, loss: 0.026698
# Decom Epoch: [49] [  22/  30] time: 132.9089, loss: 0.034144
# Decom Epoch: [49] [  23/  30] time: 133.5091, loss: 0.038157
# Decom Epoch: [49] [  24/  30] time: 134.0032, loss: 0.050757
# Decom Epoch: [49] [  25/  30] time: 134.4863, loss: 0.040151
# Decom Epoch: [49] [  26/  30] time: 134.9662, loss: 0.046633
# Decom Epoch: [49] [  27/  30] time: 135.4344, loss: 0.036664
# Decom Epoch: [49] [  28/  30] time: 135.9259, loss: 0.045968
# Decom Epoch: [49] [  29/  30] time: 136.3984, loss: 0.036713
# Decom Epoch: [49] [  30/  30] time: 136.8699, loss: 0.036097
# Decom Epoch: [50] [   1/  30] time: 137.3458, loss: 0.037754
# Decom Epoch: [50] [   2/  30] time: 137.8501, loss: 0.040187
# Decom Epoch: [50] [   3/  30] time: 138.3389, loss: 0.036081
# Decom Epoch: [50] [   4/  30] time: 138.8182, loss: 0.028292
# Decom Epoch: [50] [   5/  30] time: 139.2839, loss: 0.027914
# Decom Epoch: [50] [   6/  30] time: 139.7527, loss: 0.023632
# Decom Epoch: [50] [   7/  30] time: 140.2442, loss: 0.028026
# Decom Epoch: [50] [   8/  30] time: 140.7192, loss: 0.028454
# Decom Epoch: [50] [   9/  30] time: 141.1936, loss: 0.031733
# Decom Epoch: [50] [  10/  30] time: 141.6583, loss: 0.031033
# Decom Epoch: [50] [  11/  30] time: 142.1511, loss: 0.022636
# Decom Epoch: [50] [  12/  30] time: 142.6212, loss: 0.037555
# Decom Epoch: [50] [  13/  30] time: 143.1183, loss: 0.043091
# Decom Epoch: [50] [  14/  30] time: 143.5784, loss: 0.041452
# Decom Epoch: [50] [  15/  30] time: 144.1523, loss: 0.042926
# Decom Epoch: [50] [  16/  30] time: 144.7074, loss: 0.040291
# Decom Epoch: [50] [  17/  30] time: 145.2790, loss: 0.050210
# Decom Epoch: [50] [  18/  30] time: 145.8427, loss: 0.032278
# Decom Epoch: [50] [  19/  30] time: 146.4538, loss: 0.035946
# Decom Epoch: [50] [  20/  30] time: 147.0222, loss: 0.032797
# Decom Epoch: [50] [  21/  30] time: 147.5035, loss: 0.024283
# Decom Epoch: [50] [  22/  30] time: 147.9951, loss: 0.034269
# Decom Epoch: [50] [  23/  30] time: 148.4654, loss: 0.037758
# Decom Epoch: [50] [  24/  30] time: 148.9437, loss: 0.034964
# Decom Epoch: [50] [  25/  30] time: 149.4047, loss: 0.029613
# Decom Epoch: [50] [  26/  30] time: 149.8933, loss: 0.056076
# Decom Epoch: [50] [  27/  30] time: 150.3622, loss: 0.035480
# Decom Epoch: [50] [  28/  30] time: 150.8613, loss: 0.031498
# Decom Epoch: [50] [  29/  30] time: 151.3413, loss: 0.044613
# Decom Epoch: [50] [  30/  30] time: 151.8100, loss: 0.033743
# Evaluating for phase Decom / epoch 50...
# Decom Epoch: [51] [   1/  30] time: 152.2808, loss: 0.042832
# Decom Epoch: [51] [   2/  30] time: 152.7745, loss: 0.042451
# Decom Epoch: [51] [   3/  30] time: 153.2250, loss: 0.025424
# Decom Epoch: [51] [   4/  30] time: 153.7127, loss: 0.030410
# Decom Epoch: [51] [   5/  30] time: 154.1689, loss: 0.028430
# Decom Epoch: [51] [   6/  30] time: 154.6371, loss: 0.027433
# Decom Epoch: [51] [   7/  30] time: 155.1165, loss: 0.026229
# Decom Epoch: [51] [   8/  30] time: 155.5841, loss: 0.026117
# Decom Epoch: [51] [   9/  30] time: 156.0553, loss: 0.035816
# Decom Epoch: [51] [  10/  30] time: 156.5124, loss: 0.027875
# Decom Epoch: [51] [  11/  30] time: 157.0017, loss: 0.033791
# Decom Epoch: [51] [  12/  30] time: 157.5509, loss: 0.026686
# Decom Epoch: [51] [  13/  30] time: 158.1194, loss: 0.035030
# Decom Epoch: [51] [  14/  30] time: 158.6529, loss: 0.046984
# Decom Epoch: [51] [  15/  30] time: 159.2076, loss: 0.045533
# Decom Epoch: [51] [  16/  30] time: 159.7744, loss: 0.047377
# Decom Epoch: [51] [  17/  30] time: 160.3683, loss: 0.039276
# Decom Epoch: [51] [  18/  30] time: 160.8788, loss: 0.035363
# Decom Epoch: [51] [  19/  30] time: 161.3436, loss: 0.027198
# Decom Epoch: [51] [  20/  30] time: 161.8381, loss: 0.042830
# Decom Epoch: [51] [  21/  30] time: 162.3114, loss: 0.031482
# Decom Epoch: [51] [  22/  30] time: 162.7909, loss: 0.030959
# Decom Epoch: [51] [  23/  30] time: 163.2484, loss: 0.032539
# Decom Epoch: [51] [  24/  30] time: 163.7315, loss: 0.031174
# Decom Epoch: [51] [  25/  30] time: 164.1959, loss: 0.041562
# Decom Epoch: [51] [  26/  30] time: 164.6703, loss: 0.055386
# Decom Epoch: [51] [  27/  30] time: 165.1411, loss: 0.033734
# Decom Epoch: [51] [  28/  30] time: 165.6168, loss: 0.037654
# Decom Epoch: [51] [  29/  30] time: 166.0825, loss: 0.047132
# Decom Epoch: [51] [  30/  30] time: 166.5557, loss: 0.032371
# Decom Epoch: [52] [   1/  30] time: 167.0129, loss: 0.035024
# Decom Epoch: [52] [   2/  30] time: 167.4896, loss: 0.045472
# Decom Epoch: [52] [   3/  30] time: 167.9417, loss: 0.030293
# Decom Epoch: [52] [   4/  30] time: 168.4429, loss: 0.030631
# Decom Epoch: [52] [   5/  30] time: 168.8924, loss: 0.026868
# Decom Epoch: [52] [   6/  30] time: 169.3556, loss: 0.023333
# Decom Epoch: [52] [   7/  30] time: 169.8209, loss: 0.027686
# Decom Epoch: [52] [   8/  30] time: 170.2809, loss: 0.031108
# Decom Epoch: [52] [   9/  30] time: 170.7790, loss: 0.033367
# Decom Epoch: [52] [  10/  30] time: 171.3535, loss: 0.034607
# Decom Epoch: [52] [  11/  30] time: 171.9161, loss: 0.034653
# Decom Epoch: [52] [  12/  30] time: 172.4863, loss: 0.023335
# Decom Epoch: [52] [  13/  30] time: 173.0776, loss: 0.040490
# Decom Epoch: [52] [  14/  30] time: 173.6347, loss: 0.047926
# Decom Epoch: [52] [  15/  30] time: 174.2229, loss: 0.043824
# Decom Epoch: [52] [  16/  30] time: 174.6940, loss: 0.051045
# Decom Epoch: [52] [  17/  30] time: 175.1764, loss: 0.046126
# Decom Epoch: [52] [  18/  30] time: 175.6457, loss: 0.044205
# Decom Epoch: [52] [  19/  30] time: 176.1262, loss: 0.024120
# Decom Epoch: [52] [  20/  30] time: 176.5963, loss: 0.045910
# Decom Epoch: [52] [  21/  30] time: 177.0755, loss: 0.032274
# Decom Epoch: [52] [  22/  30] time: 177.5460, loss: 0.026924
# Decom Epoch: [52] [  23/  30] time: 178.0056, loss: 0.035894
# Decom Epoch: [52] [  24/  30] time: 178.4831, loss: 0.035728
# Decom Epoch: [52] [  25/  30] time: 178.9391, loss: 0.042519
# Decom Epoch: [52] [  26/  30] time: 179.4246, loss: 0.042951
# Decom Epoch: [52] [  27/  30] time: 179.8919, loss: 0.048245
# Decom Epoch: [52] [  28/  30] time: 180.3699, loss: 0.030269
# Decom Epoch: [52] [  29/  30] time: 180.8481, loss: 0.049954
# Decom Epoch: [52] [  30/  30] time: 181.3191, loss: 0.039772
# Decom Epoch: [53] [   1/  30] time: 181.7930, loss: 0.038296
# Decom Epoch: [53] [   2/  30] time: 182.2714, loss: 0.031408
# Decom Epoch: [53] [   3/  30] time: 182.7480, loss: 0.034566
# Decom Epoch: [53] [   4/  30] time: 183.2209, loss: 0.029304
# Decom Epoch: [53] [   5/  30] time: 183.6799, loss: 0.028112
# Decom Epoch: [53] [   6/  30] time: 184.1330, loss: 0.028456
# Decom Epoch: [53] [   7/  30] time: 184.7141, loss: 0.027224
# Decom Epoch: [53] [   8/  30] time: 185.2547, loss: 0.028904
# Decom Epoch: [53] [   9/  30] time: 185.8176, loss: 0.030393
# Decom Epoch: [53] [  10/  30] time: 186.3582, loss: 0.035872
# Decom Epoch: [53] [  11/  30] time: 186.9503, loss: 0.031555
# Decom Epoch: [53] [  12/  30] time: 187.5266, loss: 0.020473
# Decom Epoch: [53] [  13/  30] time: 188.0081, loss: 0.040151
# Decom Epoch: [53] [  14/  30] time: 188.4707, loss: 0.035036
# Decom Epoch: [53] [  15/  30] time: 188.9475, loss: 0.044688
# Decom Epoch: [53] [  16/  30] time: 189.4091, loss: 0.055243
# Decom Epoch: [53] [  17/  30] time: 189.9007, loss: 0.045261
# Decom Epoch: [53] [  18/  30] time: 190.3799, loss: 0.031227
# Decom Epoch: [53] [  19/  30] time: 190.8686, loss: 0.028684
# Decom Epoch: [53] [  20/  30] time: 191.3337, loss: 0.043089
# Decom Epoch: [53] [  21/  30] time: 191.8129, loss: 0.032179
# Decom Epoch: [53] [  22/  30] time: 192.2857, loss: 0.026164
# Decom Epoch: [53] [  23/  30] time: 192.7497, loss: 0.028162
# Decom Epoch: [53] [  24/  30] time: 193.2342, loss: 0.034771
# Decom Epoch: [53] [  25/  30] time: 193.6889, loss: 0.035649
# Decom Epoch: [53] [  26/  30] time: 194.1627, loss: 0.034870
# Decom Epoch: [53] [  27/  30] time: 194.6236, loss: 0.049222
# Decom Epoch: [53] [  28/  30] time: 195.1049, loss: 0.036293
# Decom Epoch: [53] [  29/  30] time: 195.5753, loss: 0.033959
# Decom Epoch: [53] [  30/  30] time: 196.0643, loss: 0.045897
# Decom Epoch: [54] [   1/  30] time: 196.5177, loss: 0.030476
# Decom Epoch: [54] [   2/  30] time: 196.9911, loss: 0.041968
# Decom Epoch: [54] [   3/  30] time: 197.4646, loss: 0.043814
# Decom Epoch: [54] [   4/  30] time: 198.0287, loss: 0.032080
# Decom Epoch: [54] [   5/  30] time: 198.5847, loss: 0.028628
# Decom Epoch: [54] [   6/  30] time: 199.1569, loss: 0.027659
# Decom Epoch: [54] [   7/  30] time: 199.7163, loss: 0.026354
# Decom Epoch: [54] [   8/  30] time: 200.2944, loss: 0.026097
# Decom Epoch: [54] [   9/  30] time: 200.8671, loss: 0.030829
# Decom Epoch: [54] [  10/  30] time: 201.3864, loss: 0.033337
# Decom Epoch: [54] [  11/  30] time: 201.8630, loss: 0.030270
# Decom Epoch: [54] [  12/  30] time: 202.3503, loss: 0.023907
# Decom Epoch: [54] [  13/  30] time: 202.8314, loss: 0.031948
# Decom Epoch: [54] [  14/  30] time: 203.3063, loss: 0.043271
# Decom Epoch: [54] [  15/  30] time: 203.7793, loss: 0.042860
# Decom Epoch: [54] [  16/  30] time: 204.2499, loss: 0.044758
# Decom Epoch: [54] [  17/  30] time: 204.7413, loss: 0.044796
# Decom Epoch: [54] [  18/  30] time: 205.2086, loss: 0.042473
# Decom Epoch: [54] [  19/  30] time: 205.6878, loss: 0.035020
# Decom Epoch: [54] [  20/  30] time: 206.1561, loss: 0.032776
# Decom Epoch: [54] [  21/  30] time: 206.6340, loss: 0.037342
# Decom Epoch: [54] [  22/  30] time: 207.1047, loss: 0.021431
# Decom Epoch: [54] [  23/  30] time: 207.5915, loss: 0.037194
# Decom Epoch: [54] [  24/  30] time: 208.0702, loss: 0.031417
# Decom Epoch: [54] [  25/  30] time: 208.5471, loss: 0.039889
# Decom Epoch: [54] [  26/  30] time: 209.0326, loss: 0.036285
# Decom Epoch: [54] [  27/  30] time: 209.5121, loss: 0.052184
# Decom Epoch: [54] [  28/  30] time: 209.9983, loss: 0.034815
# Decom Epoch: [54] [  29/  30] time: 210.4705, loss: 0.031739
# Decom Epoch: [54] [  30/  30] time: 210.9591, loss: 0.046818
# Decom Epoch: [55] [   1/  30] time: 211.5020, loss: 0.031306
# Decom Epoch: [55] [   2/  30] time: 212.0645, loss: 0.037312
# Decom Epoch: [55] [   3/  30] time: 212.6252, loss: 0.048958
# Decom Epoch: [55] [   4/  30] time: 213.1913, loss: 0.027946
# Decom Epoch: [55] [   5/  30] time: 213.7511, loss: 0.034517
# Decom Epoch: [55] [   6/  30] time: 214.3124, loss: 0.026177
# Decom Epoch: [55] [   7/  30] time: 214.8414, loss: 0.023409
# Decom Epoch: [55] [   8/  30] time: 215.3082, loss: 0.027148
# Decom Epoch: [55] [   9/  30] time: 215.7863, loss: 0.023948
# Decom Epoch: [55] [  10/  30] time: 216.2476, loss: 0.031029
# Decom Epoch: [55] [  11/  30] time: 216.7367, loss: 0.032526
# Decom Epoch: [55] [  12/  30] time: 217.2043, loss: 0.031884
# Decom Epoch: [55] [  13/  30] time: 217.6970, loss: 0.030708
# Decom Epoch: [55] [  14/  30] time: 218.1653, loss: 0.035911
# Decom Epoch: [55] [  15/  30] time: 218.6492, loss: 0.043115
# Decom Epoch: [55] [  16/  30] time: 219.1186, loss: 0.037078
# Decom Epoch: [55] [  17/  30] time: 219.6019, loss: 0.046052
# Decom Epoch: [55] [  18/  30] time: 220.0656, loss: 0.035361
# Decom Epoch: [55] [  19/  30] time: 220.5650, loss: 0.031482
# Decom Epoch: [55] [  20/  30] time: 221.0234, loss: 0.023121
# Decom Epoch: [55] [  21/  30] time: 221.4944, loss: 0.039992
# Decom Epoch: [55] [  22/  30] time: 221.9764, loss: 0.025863
# Decom Epoch: [55] [  23/  30] time: 222.4484, loss: 0.028342
# Decom Epoch: [55] [  24/  30] time: 222.9504, loss: 0.026168
# Decom Epoch: [55] [  25/  30] time: 223.4279, loss: 0.033280
# Decom Epoch: [55] [  26/  30] time: 223.9281, loss: 0.043014
# Decom Epoch: [55] [  27/  30] time: 224.3977, loss: 0.045455
# Decom Epoch: [55] [  28/  30] time: 224.9534, loss: 0.042666
# Decom Epoch: [55] [  29/  30] time: 225.5173, loss: 0.024939
# Decom Epoch: [55] [  30/  30] time: 226.0992, loss: 0.041149
# Decom Epoch: [56] [   1/  30] time: 226.6560, loss: 0.031513
# Decom Epoch: [56] [   2/  30] time: 227.2366, loss: 0.043189
# Decom Epoch: [56] [   3/  30] time: 227.7991, loss: 0.039694
# Decom Epoch: [56] [   4/  30] time: 228.3264, loss: 0.033035
# Decom Epoch: [56] [   5/  30] time: 228.8008, loss: 0.027237
# Decom Epoch: [56] [   6/  30] time: 229.2869, loss: 0.027170
# Decom Epoch: [56] [   7/  30] time: 229.7778, loss: 0.022923
# Decom Epoch: [56] [   8/  30] time: 230.2510, loss: 0.023281
# Decom Epoch: [56] [   9/  30] time: 230.7309, loss: 0.026424
# Decom Epoch: [56] [  10/  30] time: 231.2003, loss: 0.027315
# Decom Epoch: [56] [  11/  30] time: 231.6656, loss: 0.032197
# Decom Epoch: [56] [  12/  30] time: 232.1292, loss: 0.028475
# Decom Epoch: [56] [  13/  30] time: 232.6071, loss: 0.025505
# Decom Epoch: [56] [  14/  30] time: 233.0716, loss: 0.032927
# Decom Epoch: [56] [  15/  30] time: 233.5367, loss: 0.047454
# Decom Epoch: [56] [  16/  30] time: 234.0054, loss: 0.042687
# Decom Epoch: [56] [  17/  30] time: 234.4644, loss: 0.053223
# Decom Epoch: [56] [  18/  30] time: 234.9522, loss: 0.042677
# Decom Epoch: [56] [  19/  30] time: 235.4176, loss: 0.036585
# Decom Epoch: [56] [  20/  30] time: 235.9004, loss: 0.032219
# Decom Epoch: [56] [  21/  30] time: 236.3688, loss: 0.038123
# Decom Epoch: [56] [  22/  30] time: 236.8409, loss: 0.030529
# Decom Epoch: [56] [  23/  30] time: 237.3091, loss: 0.026960
# Decom Epoch: [56] [  24/  30] time: 237.7845, loss: 0.031619
# Decom Epoch: [56] [  25/  30] time: 238.2814, loss: 0.043089
# Decom Epoch: [56] [  26/  30] time: 238.8455, loss: 0.038510
# Decom Epoch: [56] [  27/  30] time: 239.3958, loss: 0.044822
# Decom Epoch: [56] [  28/  30] time: 239.9503, loss: 0.042364
# Decom Epoch: [56] [  29/  30] time: 240.5270, loss: 0.029377
# Decom Epoch: [56] [  30/  30] time: 241.1031, loss: 0.038764
# Decom Epoch: [57] [   1/  30] time: 241.6934, loss: 0.042701
# Decom Epoch: [57] [   2/  30] time: 242.1598, loss: 0.035930
# Decom Epoch: [57] [   3/  30] time: 242.6426, loss: 0.034821
# Decom Epoch: [57] [   4/  30] time: 243.1218, loss: 0.036469
# Decom Epoch: [57] [   5/  30] time: 243.6060, loss: 0.027576
# Decom Epoch: [57] [   6/  30] time: 244.0623, loss: 0.028287
# Decom Epoch: [57] [   7/  30] time: 244.5401, loss: 0.025830
# Decom Epoch: [57] [   8/  30] time: 244.9940, loss: 0.029798
# Decom Epoch: [57] [   9/  30] time: 245.4697, loss: 0.026755
# Decom Epoch: [57] [  10/  30] time: 245.9258, loss: 0.030830
# Decom Epoch: [57] [  11/  30] time: 246.3790, loss: 0.029981
# Decom Epoch: [57] [  12/  30] time: 246.8568, loss: 0.034303
# Decom Epoch: [57] [  13/  30] time: 247.3138, loss: 0.022472
# Decom Epoch: [57] [  14/  30] time: 247.7997, loss: 0.029138
# Decom Epoch: [57] [  15/  30] time: 248.2753, loss: 0.031642
# Decom Epoch: [57] [  16/  30] time: 248.7500, loss: 0.041899
# Decom Epoch: [57] [  17/  30] time: 249.2196, loss: 0.033255
# Decom Epoch: [57] [  18/  30] time: 249.7046, loss: 0.047939
# Decom Epoch: [57] [  19/  30] time: 250.1678, loss: 0.034616
# Decom Epoch: [57] [  20/  30] time: 250.6639, loss: 0.031563
# Decom Epoch: [57] [  21/  30] time: 251.1291, loss: 0.032797
# Decom Epoch: [57] [  22/  30] time: 251.6118, loss: 0.028744
# Decom Epoch: [57] [  23/  30] time: 252.1728, loss: 0.023828
# Decom Epoch: [57] [  24/  30] time: 252.7431, loss: 0.026654
# Decom Epoch: [57] [  25/  30] time: 253.3246, loss: 0.030954
# Decom Epoch: [57] [  26/  30] time: 253.8859, loss: 0.035688
# Decom Epoch: [57] [  27/  30] time: 254.4763, loss: 0.033673
# Decom Epoch: [57] [  28/  30] time: 255.0720, loss: 0.046644
# Decom Epoch: [57] [  29/  30] time: 255.5631, loss: 0.029222
# Decom Epoch: [57] [  30/  30] time: 256.0365, loss: 0.027858
# Decom Epoch: [58] [   1/  30] time: 256.5406, loss: 0.045252
# Decom Epoch: [58] [   2/  30] time: 257.0204, loss: 0.032216
# Decom Epoch: [58] [   3/  30] time: 257.5127, loss: 0.032127
# Decom Epoch: [58] [   4/  30] time: 257.9839, loss: 0.046074
# Decom Epoch: [58] [   5/  30] time: 258.4716, loss: 0.023348
# Decom Epoch: [58] [   6/  30] time: 258.9529, loss: 0.031319
# Decom Epoch: [58] [   7/  30] time: 259.4329, loss: 0.025425
# Decom Epoch: [58] [   8/  30] time: 259.9075, loss: 0.023177
# Decom Epoch: [58] [   9/  30] time: 260.3731, loss: 0.027435
# Decom Epoch: [58] [  10/  30] time: 260.8505, loss: 0.024138
# Decom Epoch: [58] [  11/  30] time: 261.3203, loss: 0.027822
# Decom Epoch: [58] [  12/  30] time: 261.7970, loss: 0.033946
# Decom Epoch: [58] [  13/  30] time: 262.2672, loss: 0.029908
# Decom Epoch: [58] [  14/  30] time: 262.7404, loss: 0.030173
# Decom Epoch: [58] [  15/  30] time: 263.2191, loss: 0.042298
# Decom Epoch: [58] [  16/  30] time: 263.6928, loss: 0.034232
# Decom Epoch: [58] [  17/  30] time: 264.1536, loss: 0.037896
# Decom Epoch: [58] [  18/  30] time: 264.6450, loss: 0.055673
# Decom Epoch: [58] [  19/  30] time: 265.1135, loss: 0.045408
# Decom Epoch: [58] [  20/  30] time: 265.6720, loss: 0.035603
# Decom Epoch: [58] [  21/  30] time: 266.2443, loss: 0.023474
# Decom Epoch: [58] [  22/  30] time: 266.8091, loss: 0.045082
# Decom Epoch: [58] [  23/  30] time: 267.3850, loss: 0.022110
# Decom Epoch: [58] [  24/  30] time: 267.9697, loss: 0.025952
# Decom Epoch: [58] [  25/  30] time: 268.5767, loss: 0.026974
# Decom Epoch: [58] [  26/  30] time: 269.0412, loss: 0.032876
# Decom Epoch: [58] [  27/  30] time: 269.5369, loss: 0.038965
# Decom Epoch: [58] [  28/  30] time: 270.0038, loss: 0.044580
# Decom Epoch: [58] [  29/  30] time: 270.4960, loss: 0.043809
# Decom Epoch: [58] [  30/  30] time: 270.9641, loss: 0.031808
# Decom Epoch: [59] [   1/  30] time: 271.4548, loss: 0.055849
# Decom Epoch: [59] [   2/  30] time: 271.9277, loss: 0.030076
# Decom Epoch: [59] [   3/  30] time: 272.4048, loss: 0.033378
# Decom Epoch: [59] [   4/  30] time: 272.8689, loss: 0.042466
# Decom Epoch: [59] [   5/  30] time: 273.3356, loss: 0.026567
# Decom Epoch: [59] [   6/  30] time: 273.8209, loss: 0.022211
# Decom Epoch: [59] [   7/  30] time: 274.2867, loss: 0.028553
# Decom Epoch: [59] [   8/  30] time: 274.7665, loss: 0.024234
# Decom Epoch: [59] [   9/  30] time: 275.2266, loss: 0.025475
# Decom Epoch: [59] [  10/  30] time: 275.7061, loss: 0.033600
# Decom Epoch: [59] [  11/  30] time: 276.1631, loss: 0.025891
# Decom Epoch: [59] [  12/  30] time: 276.6329, loss: 0.033160
# Decom Epoch: [59] [  13/  30] time: 277.0789, loss: 0.028463
# Decom Epoch: [59] [  14/  30] time: 277.5561, loss: 0.025095
# Decom Epoch: [59] [  15/  30] time: 278.0166, loss: 0.029653
# Decom Epoch: [59] [  16/  30] time: 278.5051, loss: 0.047595
# Decom Epoch: [59] [  17/  30] time: 279.0521, loss: 0.030049
# Decom Epoch: [59] [  18/  30] time: 279.6062, loss: 0.041304
# Decom Epoch: [59] [  19/  30] time: 280.1685, loss: 0.035287
# Decom Epoch: [59] [  20/  30] time: 280.7252, loss: 0.035240
# Decom Epoch: [59] [  21/  30] time: 281.3252, loss: 0.024593
# Decom Epoch: [59] [  22/  30] time: 281.9043, loss: 0.037052
# Decom Epoch: [59] [  23/  30] time: 282.4243, loss: 0.028402
# Decom Epoch: [59] [  24/  30] time: 282.9036, loss: 0.029485
# Decom Epoch: [59] [  25/  30] time: 283.3906, loss: 0.032792
# Decom Epoch: [59] [  26/  30] time: 283.8666, loss: 0.028706
# Decom Epoch: [59] [  27/  30] time: 284.3588, loss: 0.029818
# Decom Epoch: [59] [  28/  30] time: 284.8141, loss: 0.040671
# Decom Epoch: [59] [  29/  30] time: 285.2937, loss: 0.039961
# Decom Epoch: [59] [  30/  30] time: 285.7736, loss: 0.025598
# Decom Epoch: [60] [   1/  30] time: 286.2706, loss: 0.034744
# Decom Epoch: [60] [   2/  30] time: 286.7359, loss: 0.041541
# Decom Epoch: [60] [   3/  30] time: 287.2233, loss: 0.030538
# Decom Epoch: [60] [   4/  30] time: 287.6877, loss: 0.032844
# Decom Epoch: [60] [   5/  30] time: 288.1713, loss: 0.031697
# Decom Epoch: [60] [   6/  30] time: 288.6447, loss: 0.027803
# Decom Epoch: [60] [   7/  30] time: 289.1023, loss: 0.028786
# Decom Epoch: [60] [   8/  30] time: 289.5708, loss: 0.025807
# Decom Epoch: [60] [   9/  30] time: 290.0619, loss: 0.026793
# Decom Epoch: [60] [  10/  30] time: 290.5286, loss: 0.029213
# Decom Epoch: [60] [  11/  30] time: 290.9944, loss: 0.025452
# Decom Epoch: [60] [  12/  30] time: 291.4671, loss: 0.032562
# Decom Epoch: [60] [  13/  30] time: 291.9164, loss: 0.031715
# Decom Epoch: [60] [  14/  30] time: 292.4610, loss: 0.022044
# Decom Epoch: [60] [  15/  30] time: 293.0144, loss: 0.025706
# Decom Epoch: [60] [  16/  30] time: 293.5693, loss: 0.038765
# Decom Epoch: [60] [  17/  30] time: 294.1357, loss: 0.046046
# Decom Epoch: [60] [  18/  30] time: 294.7147, loss: 0.043732
# Decom Epoch: [60] [  19/  30] time: 295.2795, loss: 0.036252
# Decom Epoch: [60] [  20/  30] time: 295.7726, loss: 0.046080
# Decom Epoch: [60] [  21/  30] time: 296.2603, loss: 0.032375
# Decom Epoch: [60] [  22/  30] time: 296.7241, loss: 0.030743
# Decom Epoch: [60] [  23/  30] time: 297.2104, loss: 0.033214
# Decom Epoch: [60] [  24/  30] time: 297.6798, loss: 0.027017
# Decom Epoch: [60] [  25/  30] time: 298.1685, loss: 0.028720
# Decom Epoch: [60] [  26/  30] time: 298.6416, loss: 0.029709
# Decom Epoch: [60] [  27/  30] time: 299.1280, loss: 0.030081
# Decom Epoch: [60] [  28/  30] time: 299.5997, loss: 0.039243
# Decom Epoch: [60] [  29/  30] time: 300.0918, loss: 0.048586
# Decom Epoch: [60] [  30/  30] time: 300.5652, loss: 0.033881
# Evaluating for phase Decom / epoch 60...
# Decom Epoch: [61] [   1/  30] time: 301.0531, loss: 0.027926
# Decom Epoch: [61] [   2/  30] time: 301.5237, loss: 0.043826
# Decom Epoch: [61] [   3/  30] time: 302.0019, loss: 0.035855
# Decom Epoch: [61] [   4/  30] time: 302.4779, loss: 0.031907
# Decom Epoch: [61] [   5/  30] time: 302.9783, loss: 0.036658
# Decom Epoch: [61] [   6/  30] time: 303.4452, loss: 0.027359
# Decom Epoch: [61] [   7/  30] time: 303.9241, loss: 0.023973
# Decom Epoch: [61] [   8/  30] time: 304.3904, loss: 0.023146
# Decom Epoch: [61] [   9/  30] time: 304.8440, loss: 0.032443
# Decom Epoch: [61] [  10/  30] time: 305.3263, loss: 0.031544
# Decom Epoch: [61] [  11/  30] time: 305.8561, loss: 0.024946
# Decom Epoch: [61] [  12/  30] time: 306.4215, loss: 0.028000
# Decom Epoch: [61] [  13/  30] time: 306.9512, loss: 0.027695
# Decom Epoch: [61] [  14/  30] time: 307.5231, loss: 0.028361
# Decom Epoch: [61] [  15/  30] time: 308.0863, loss: 0.023811
# Decom Epoch: [61] [  16/  30] time: 308.6853, loss: 0.041639
# Decom Epoch: [61] [  17/  30] time: 309.2239, loss: 0.033216
# Decom Epoch: [61] [  18/  30] time: 309.7098, loss: 0.041325
# Decom Epoch: [61] [  19/  30] time: 310.1830, loss: 0.039516
# Decom Epoch: [61] [  20/  30] time: 310.6676, loss: 0.037216
# Decom Epoch: [61] [  21/  30] time: 311.1664, loss: 0.033398
# Decom Epoch: [61] [  22/  30] time: 311.6580, loss: 0.023867
# Decom Epoch: [61] [  23/  30] time: 312.1315, loss: 0.045420
# Decom Epoch: [61] [  24/  30] time: 312.5920, loss: 0.025500
# Decom Epoch: [61] [  25/  30] time: 313.0709, loss: 0.034475
# Decom Epoch: [61] [  26/  30] time: 313.5490, loss: 0.025595
# Decom Epoch: [61] [  27/  30] time: 314.0447, loss: 0.030798
# Decom Epoch: [61] [  28/  30] time: 314.5173, loss: 0.040230
# Decom Epoch: [61] [  29/  30] time: 315.0007, loss: 0.044147
# Decom Epoch: [61] [  30/  30] time: 315.4678, loss: 0.041903
# Decom Epoch: [62] [   1/  30] time: 315.9524, loss: 0.028161
# Decom Epoch: [62] [   2/  30] time: 316.4222, loss: 0.054058
# Decom Epoch: [62] [   3/  30] time: 316.9057, loss: 0.030874
# Decom Epoch: [62] [   4/  30] time: 317.3558, loss: 0.031351
# Decom Epoch: [62] [   5/  30] time: 317.8445, loss: 0.039891
# Decom Epoch: [62] [   6/  30] time: 318.3028, loss: 0.030157
# Decom Epoch: [62] [   7/  30] time: 318.7726, loss: 0.028116
# Decom Epoch: [62] [   8/  30] time: 319.2841, loss: 0.023860
# Decom Epoch: [62] [   9/  30] time: 319.8447, loss: 0.024285
# Decom Epoch: [62] [  10/  30] time: 320.4269, loss: 0.022071
# Decom Epoch: [62] [  11/  30] time: 321.0046, loss: 0.025223
# Decom Epoch: [62] [  12/  30] time: 321.5603, loss: 0.026078
# Decom Epoch: [62] [  13/  30] time: 322.1288, loss: 0.034362
# Decom Epoch: [62] [  14/  30] time: 322.6787, loss: 0.030432
# Decom Epoch: [62] [  15/  30] time: 323.1454, loss: 0.029091
# Decom Epoch: [62] [  16/  30] time: 323.6240, loss: 0.029268
# Decom Epoch: [62] [  17/  30] time: 324.0940, loss: 0.036602
# Decom Epoch: [62] [  18/  30] time: 324.5710, loss: 0.033776
# Decom Epoch: [62] [  19/  30] time: 325.0363, loss: 0.047864
# Decom Epoch: [62] [  20/  30] time: 325.5150, loss: 0.048807
# Decom Epoch: [62] [  21/  30] time: 325.9789, loss: 0.034082
# Decom Epoch: [62] [  22/  30] time: 326.4597, loss: 0.024248
# Decom Epoch: [62] [  23/  30] time: 326.9179, loss: 0.040346
# Decom Epoch: [62] [  24/  30] time: 327.3951, loss: 0.024389
# Decom Epoch: [62] [  25/  30] time: 327.8552, loss: 0.025375
# Decom Epoch: [62] [  26/  30] time: 328.3285, loss: 0.032792
# Decom Epoch: [62] [  27/  30] time: 328.8011, loss: 0.036042
# Decom Epoch: [62] [  28/  30] time: 329.2779, loss: 0.039729
# Decom Epoch: [62] [  29/  30] time: 329.7474, loss: 0.035859
# Decom Epoch: [62] [  30/  30] time: 330.2068, loss: 0.044221
# Decom Epoch: [63] [   1/  30] time: 330.6793, loss: 0.031948
# Decom Epoch: [63] [   2/  30] time: 331.1593, loss: 0.032894
# Decom Epoch: [63] [   3/  30] time: 331.6328, loss: 0.037588
# Decom Epoch: [63] [   4/  30] time: 332.0914, loss: 0.032912
# Decom Epoch: [63] [   5/  30] time: 332.5705, loss: 0.042514
# Decom Epoch: [63] [   6/  30] time: 333.1473, loss: 0.038636
# Decom Epoch: [63] [   7/  30] time: 333.7120, loss: 0.027998
# Decom Epoch: [63] [   8/  30] time: 334.2706, loss: 0.022441
# Decom Epoch: [63] [   9/  30] time: 334.8383, loss: 0.026733
# Decom Epoch: [63] [  10/  30] time: 335.4077, loss: 0.025984
# Decom Epoch: [63] [  11/  30] time: 335.9557, loss: 0.024324
# Decom Epoch: [63] [  12/  30] time: 336.4370, loss: 0.025135
# Decom Epoch: [63] [  13/  30] time: 336.8898, loss: 0.024233
# Decom Epoch: [63] [  14/  30] time: 337.3661, loss: 0.029172
# Decom Epoch: [63] [  15/  30] time: 337.8334, loss: 0.020057
# Decom Epoch: [63] [  16/  30] time: 338.3162, loss: 0.034085
# Decom Epoch: [63] [  17/  30] time: 338.7982, loss: 0.039924
# Decom Epoch: [63] [  18/  30] time: 339.2818, loss: 0.031804
# Decom Epoch: [63] [  19/  30] time: 339.7483, loss: 0.046764
# Decom Epoch: [63] [  20/  30] time: 340.2355, loss: 0.039834
# Decom Epoch: [63] [  21/  30] time: 340.7171, loss: 0.032281
# Decom Epoch: [63] [  22/  30] time: 341.2014, loss: 0.033875
# Decom Epoch: [63] [  23/  30] time: 341.6949, loss: 0.034391
# Decom Epoch: [63] [  24/  30] time: 342.1834, loss: 0.029652
# Decom Epoch: [63] [  25/  30] time: 342.6459, loss: 0.023797
# Decom Epoch: [63] [  26/  30] time: 343.1257, loss: 0.021736
# Decom Epoch: [63] [  27/  30] time: 343.5912, loss: 0.033522
# Decom Epoch: [63] [  28/  30] time: 344.0732, loss: 0.032026
# Decom Epoch: [63] [  29/  30] time: 344.5505, loss: 0.031320
# Decom Epoch: [63] [  30/  30] time: 345.0241, loss: 0.043249
# Decom Epoch: [64] [   1/  30] time: 345.5066, loss: 0.029693
# Decom Epoch: [64] [   2/  30] time: 345.9734, loss: 0.033916
# Decom Epoch: [64] [   3/  30] time: 346.5498, loss: 0.044076
# Decom Epoch: [64] [   4/  30] time: 347.1104, loss: 0.035073
# Decom Epoch: [64] [   5/  30] time: 347.6709, loss: 0.033838
# Decom Epoch: [64] [   6/  30] time: 348.2375, loss: 0.038233
# Decom Epoch: [64] [   7/  30] time: 348.7994, loss: 0.031121
# Decom Epoch: [64] [   8/  30] time: 349.3766, loss: 0.025715
# Decom Epoch: [64] [   9/  30] time: 349.8503, loss: 0.025287
# Decom Epoch: [64] [  10/  30] time: 350.3084, loss: 0.027121
# Decom Epoch: [64] [  11/  30] time: 350.7904, loss: 0.027154
# Decom Epoch: [64] [  12/  30] time: 351.2459, loss: 0.024387
# Decom Epoch: [64] [  13/  30] time: 351.7029, loss: 0.027783
# Decom Epoch: [64] [  14/  30] time: 352.1824, loss: 0.026688
# Decom Epoch: [64] [  15/  30] time: 352.6519, loss: 0.031302
# Decom Epoch: [64] [  16/  30] time: 353.1450, loss: 0.031280
# Decom Epoch: [64] [  17/  30] time: 353.6347, loss: 0.038671
# Decom Epoch: [64] [  18/  30] time: 354.1225, loss: 0.038065
# Decom Epoch: [64] [  19/  30] time: 354.5840, loss: 0.040213
# Decom Epoch: [64] [  20/  30] time: 355.0639, loss: 0.050151
# Decom Epoch: [64] [  21/  30] time: 355.5172, loss: 0.040986
# Decom Epoch: [64] [  22/  30] time: 356.0070, loss: 0.035889
# Decom Epoch: [64] [  23/  30] time: 356.4719, loss: 0.028000
# Decom Epoch: [64] [  24/  30] time: 356.9470, loss: 0.047013
# Decom Epoch: [64] [  25/  30] time: 357.4046, loss: 0.033134
# Decom Epoch: [64] [  26/  30] time: 357.8772, loss: 0.028670
# Decom Epoch: [64] [  27/  30] time: 358.3407, loss: 0.031648
# Decom Epoch: [64] [  28/  30] time: 358.7983, loss: 0.028132
# Decom Epoch: [64] [  29/  30] time: 359.2765, loss: 0.036314
# Decom Epoch: [64] [  30/  30] time: 359.8239, loss: 0.039755
# Decom Epoch: [65] [   1/  30] time: 360.4045, loss: 0.034803
# Decom Epoch: [65] [   2/  30] time: 360.9548, loss: 0.032948
# Decom Epoch: [65] [   3/  30] time: 361.5402, loss: 0.044358
# Decom Epoch: [65] [   4/  30] time: 362.0925, loss: 0.028019
# Decom Epoch: [65] [   5/  30] time: 362.6700, loss: 0.033339
# Decom Epoch: [65] [   6/  30] time: 363.1841, loss: 0.040840
# Decom Epoch: [65] [   7/  30] time: 363.6558, loss: 0.028996
# Decom Epoch: [65] [   8/  30] time: 364.1102, loss: 0.027545
# Decom Epoch: [65] [   9/  30] time: 364.5871, loss: 0.022657
# Decom Epoch: [65] [  10/  30] time: 365.0378, loss: 0.025190
# Decom Epoch: [65] [  11/  30] time: 365.5177, loss: 0.021114
# Decom Epoch: [65] [  12/  30] time: 365.9681, loss: 0.028241
# Decom Epoch: [65] [  13/  30] time: 366.4488, loss: 0.032085
# Decom Epoch: [65] [  14/  30] time: 366.9000, loss: 0.029712
# Decom Epoch: [65] [  15/  30] time: 367.3823, loss: 0.032323
# Decom Epoch: [65] [  16/  30] time: 367.8535, loss: 0.023703
# Decom Epoch: [65] [  17/  30] time: 368.3154, loss: 0.031525
# Decom Epoch: [65] [  18/  30] time: 368.7974, loss: 0.035841
# Decom Epoch: [65] [  19/  30] time: 369.2617, loss: 0.034980
# Decom Epoch: [65] [  20/  30] time: 369.7419, loss: 0.044404
# Decom Epoch: [65] [  21/  30] time: 370.2130, loss: 0.041163
# Decom Epoch: [65] [  22/  30] time: 370.7181, loss: 0.036309
# Decom Epoch: [65] [  23/  30] time: 371.1829, loss: 0.025590
# Decom Epoch: [65] [  24/  30] time: 371.6592, loss: 0.035633
# Decom Epoch: [65] [  25/  30] time: 372.1404, loss: 0.024822
# Decom Epoch: [65] [  26/  30] time: 372.6237, loss: 0.026772
# Decom Epoch: [65] [  27/  30] time: 373.1810, loss: 0.030389
# Decom Epoch: [65] [  28/  30] time: 373.7669, loss: 0.032089
# Decom Epoch: [65] [  29/  30] time: 374.3255, loss: 0.034078
# Decom Epoch: [65] [  30/  30] time: 374.8766, loss: 0.040114
# Decom Epoch: [66] [   1/  30] time: 375.4565, loss: 0.036545
# Decom Epoch: [66] [   2/  30] time: 376.0448, loss: 0.031643
# Decom Epoch: [66] [   3/  30] time: 376.5871, loss: 0.037306
# Decom Epoch: [66] [   4/  30] time: 377.0645, loss: 0.036770
# Decom Epoch: [66] [   5/  30] time: 377.5391, loss: 0.026374
# Decom Epoch: [66] [   6/  30] time: 378.0066, loss: 0.030650
# Decom Epoch: [66] [   7/  30] time: 378.4864, loss: 0.035563
# Decom Epoch: [66] [   8/  30] time: 378.9476, loss: 0.024610
# Decom Epoch: [66] [   9/  30] time: 379.4204, loss: 0.023242
# Decom Epoch: [66] [  10/  30] time: 379.8750, loss: 0.023755
# Decom Epoch: [66] [  11/  30] time: 380.3417, loss: 0.032292
# Decom Epoch: [66] [  12/  30] time: 380.7951, loss: 0.023734
# Decom Epoch: [66] [  13/  30] time: 381.2596, loss: 0.023791
# Decom Epoch: [66] [  14/  30] time: 381.7295, loss: 0.027278
# Decom Epoch: [66] [  15/  30] time: 382.2085, loss: 0.026257
# Decom Epoch: [66] [  16/  30] time: 382.6935, loss: 0.023465
# Decom Epoch: [66] [  17/  30] time: 383.1808, loss: 0.031391
# Decom Epoch: [66] [  18/  30] time: 383.6957, loss: 0.041626
# Decom Epoch: [66] [  19/  30] time: 384.1974, loss: 0.037029
# Decom Epoch: [66] [  20/  30] time: 384.7016, loss: 0.034099
# Decom Epoch: [66] [  21/  30] time: 385.2021, loss: 0.032393
# Decom Epoch: [66] [  22/  30] time: 385.6998, loss: 0.033136
# Decom Epoch: [66] [  23/  30] time: 386.1819, loss: 0.033932
# Decom Epoch: [66] [  24/  30] time: 386.7332, loss: 0.039511
# Decom Epoch: [66] [  25/  30] time: 387.2786, loss: 0.023646
# Decom Epoch: [66] [  26/  30] time: 387.8398, loss: 0.029083
# Decom Epoch: [66] [  27/  30] time: 388.4078, loss: 0.025278
# Decom Epoch: [66] [  28/  30] time: 388.9516, loss: 0.032008
# Decom Epoch: [66] [  29/  30] time: 389.5526, loss: 0.039316
# Decom Epoch: [66] [  30/  30] time: 390.0785, loss: 0.035081
# Decom Epoch: [67] [   1/  30] time: 390.5748, loss: 0.033090
# Decom Epoch: [67] [   2/  30] time: 391.0376, loss: 0.034031
# Decom Epoch: [67] [   3/  30] time: 391.5264, loss: 0.035761
# Decom Epoch: [67] [   4/  30] time: 392.0015, loss: 0.037953
# Decom Epoch: [67] [   5/  30] time: 392.5139, loss: 0.029212
# Decom Epoch: [67] [   6/  30] time: 392.9674, loss: 0.038902
# ...
# Relight Epoch: [92] [  23/  30] time: 1372.9893, loss: 0.141991
# Relight Epoch: [92] [  24/  30] time: 1373.4741, loss: 0.196829
# Relight Epoch: [92] [  25/  30] time: 1373.9531, loss: 0.154272
# Relight Epoch: [92] [  26/  30] time: 1374.4069, loss: 0.138521
# Relight Epoch: [92] [  27/  30] time: 1374.8875, loss: 0.114306
# Relight Epoch: [92] [  28/  30] time: 1375.3701, loss: 0.129560
# Relight Epoch: [92] [  29/  30] time: 1375.8517, loss: 0.151295
# Relight Epoch: [92] [  30/  30] time: 1376.2962, loss: 0.156325
# Relight Epoch: [93] [   1/  30] time: 1376.7731, loss: 0.151517
# Relight Epoch: [93] [   2/  30] time: 1377.2412, loss: 0.177260
# Relight Epoch: [93] [   3/  30] time: 1377.7084, loss: 0.138713
# Relight Epoch: [93] [   4/  30] time: 1378.1642, loss: 0.129531
# Relight Epoch: [93] [   5/  30] time: 1378.6424, loss: 0.168986
# Relight Epoch: [93] [   6/  30] time: 1379.0991, loss: 0.163829
# Relight Epoch: [93] [   7/  30] time: 1379.5659, loss: 0.157132
# Relight Epoch: [93] [   8/  30] time: 1380.0360, loss: 0.213481
# Relight Epoch: [93] [   9/  30] time: 1380.5075, loss: 0.180966
# Relight Epoch: [93] [  10/  30] time: 1380.9781, loss: 0.185331
# Relight Epoch: [93] [  11/  30] time: 1381.4558, loss: 0.154517
# Relight Epoch: [93] [  12/  30] time: 1381.9420, loss: 0.155622
# Relight Epoch: [93] [  13/  30] time: 1382.4977, loss: 0.140451
# Relight Epoch: [93] [  14/  30] time: 1383.0942, loss: 0.124665
# Relight Epoch: [93] [  15/  30] time: 1383.6556, loss: 0.143893
# Relight Epoch: [93] [  16/  30] time: 1384.2399, loss: 0.131175
# Relight Epoch: [93] [  17/  30] time: 1384.7892, loss: 0.130463
# Relight Epoch: [93] [  18/  30] time: 1385.3852, loss: 0.128181
# Relight Epoch: [93] [  19/  30] time: 1385.8914, loss: 0.176032
# Relight Epoch: [93] [  20/  30] time: 1386.3795, loss: 0.146033
# Relight Epoch: [93] [  21/  30] time: 1386.8409, loss: 0.111424
# Relight Epoch: [93] [  22/  30] time: 1387.3245, loss: 0.108302
# Relight Epoch: [93] [  23/  30] time: 1387.7837, loss: 0.139799
# Relight Epoch: [93] [  24/  30] time: 1388.2783, loss: 0.180356
# Relight Epoch: [93] [  25/  30] time: 1388.7450, loss: 0.180046
# Relight Epoch: [93] [  26/  30] time: 1389.2091, loss: 0.151268
# Relight Epoch: [93] [  27/  30] time: 1389.6858, loss: 0.135986
# Relight Epoch: [93] [  28/  30] time: 1390.1658, loss: 0.121906
# Relight Epoch: [93] [  29/  30] time: 1390.6482, loss: 0.144987
# Relight Epoch: [93] [  30/  30] time: 1391.1069, loss: 0.187616
# Relight Epoch: [94] [   1/  30] time: 1391.5932, loss: 0.133979
# Relight Epoch: [94] [   2/  30] time: 1392.0508, loss: 0.176552
# Relight Epoch: [94] [   3/  30] time: 1392.5226, loss: 0.148229
# Relight Epoch: [94] [   4/  30] time: 1392.9813, loss: 0.162917
# Relight Epoch: [94] [   5/  30] time: 1393.4671, loss: 0.148956
# Relight Epoch: [94] [   6/  30] time: 1393.9202, loss: 0.155645
# Relight Epoch: [94] [   7/  30] time: 1394.3992, loss: 0.168306
# Relight Epoch: [94] [   8/  30] time: 1394.8645, loss: 0.170682
# Relight Epoch: [94] [   9/  30] time: 1395.3571, loss: 0.224887
# Relight Epoch: [94] [  10/  30] time: 1395.8693, loss: 0.154364
# Relight Epoch: [94] [  11/  30] time: 1396.4363, loss: 0.171250
# Relight Epoch: [94] [  12/  30] time: 1397.0034, loss: 0.157503
# Relight Epoch: [94] [  13/  30] time: 1397.5784, loss: 0.171357
# Relight Epoch: [94] [  14/  30] time: 1398.1478, loss: 0.130655
# Relight Epoch: [94] [  15/  30] time: 1398.7544, loss: 0.144604
# Relight Epoch: [94] [  16/  30] time: 1399.3183, loss: 0.117111
# Relight Epoch: [94] [  17/  30] time: 1399.7810, loss: 0.117711
# Relight Epoch: [94] [  18/  30] time: 1400.2633, loss: 0.117732
# Relight Epoch: [94] [  19/  30] time: 1400.7371, loss: 0.131855
# Relight Epoch: [94] [  20/  30] time: 1401.2217, loss: 0.166136
# Relight Epoch: [94] [  21/  30] time: 1401.6941, loss: 0.116376
# Relight Epoch: [94] [  22/  30] time: 1402.1730, loss: 0.103365
# Relight Epoch: [94] [  23/  30] time: 1402.6399, loss: 0.117769
# Relight Epoch: [94] [  24/  30] time: 1403.1196, loss: 0.137165
# Relight Epoch: [94] [  25/  30] time: 1403.5959, loss: 0.199330
# Relight Epoch: [94] [  26/  30] time: 1404.0962, loss: 0.125307
# Relight Epoch: [94] [  27/  30] time: 1404.5758, loss: 0.135253
# Relight Epoch: [94] [  28/  30] time: 1405.0624, loss: 0.106148
# Relight Epoch: [94] [  29/  30] time: 1405.5528, loss: 0.164908
# Relight Epoch: [94] [  30/  30] time: 1406.0167, loss: 0.162638
# Relight Epoch: [95] [   1/  30] time: 1406.4887, loss: 0.162315
# Relight Epoch: [95] [   2/  30] time: 1406.9532, loss: 0.137332
# Relight Epoch: [95] [   3/  30] time: 1407.4379, loss: 0.161633
# Relight Epoch: [95] [   4/  30] time: 1407.9051, loss: 0.168779
# Relight Epoch: [95] [   5/  30] time: 1408.3808, loss: 0.160490
# Relight Epoch: [95] [   6/  30] time: 1408.8429, loss: 0.164597
# Relight Epoch: [95] [   7/  30] time: 1409.3400, loss: 0.149794
# Relight Epoch: [95] [   8/  30] time: 1409.8944, loss: 0.202134
# Relight Epoch: [95] [   9/  30] time: 1410.4635, loss: 0.223237
# Relight Epoch: [95] [  10/  30] time: 1411.0219, loss: 0.207478
# Relight Epoch: [95] [  11/  30] time: 1411.5899, loss: 0.172159
# Relight Epoch: [95] [  12/  30] time: 1412.1890, loss: 0.175234
# Relight Epoch: [95] [  13/  30] time: 1412.7470, loss: 0.154093
# Relight Epoch: [95] [  14/  30] time: 1413.2411, loss: 0.138516
# Relight Epoch: [95] [  15/  30] time: 1413.7101, loss: 0.140969
# Relight Epoch: [95] [  16/  30] time: 1414.2030, loss: 0.144729
# Relight Epoch: [95] [  17/  30] time: 1414.6726, loss: 0.139320
# Relight Epoch: [95] [  18/  30] time: 1415.1689, loss: 0.126006
# Relight Epoch: [95] [  19/  30] time: 1415.6378, loss: 0.129847
# Relight Epoch: [95] [  20/  30] time: 1416.1196, loss: 0.159539
# Relight Epoch: [95] [  21/  30] time: 1416.5836, loss: 0.122572
# Relight Epoch: [95] [  22/  30] time: 1417.0727, loss: 0.107910
# Relight Epoch: [95] [  23/  30] time: 1417.5464, loss: 0.095139
# Relight Epoch: [95] [  24/  30] time: 1418.0251, loss: 0.128697
# Relight Epoch: [95] [  25/  30] time: 1418.4901, loss: 0.219644
# Relight Epoch: [95] [  26/  30] time: 1418.9758, loss: 0.150692
# Relight Epoch: [95] [  27/  30] time: 1419.4380, loss: 0.130532
# Relight Epoch: [95] [  28/  30] time: 1419.9254, loss: 0.117332
# Relight Epoch: [95] [  29/  30] time: 1420.3925, loss: 0.143392
# Relight Epoch: [95] [  30/  30] time: 1420.8564, loss: 0.165901
# Relight Epoch: [96] [   1/  30] time: 1421.3320, loss: 0.190891
# Relight Epoch: [96] [   2/  30] time: 1421.7976, loss: 0.159930
# Relight Epoch: [96] [   3/  30] time: 1422.2906, loss: 0.191841
# Relight Epoch: [96] [   4/  30] time: 1422.7672, loss: 0.141504
# Relight Epoch: [96] [   5/  30] time: 1423.3518, loss: 0.130154
# Relight Epoch: [96] [   6/  30] time: 1423.8999, loss: 0.150077
# Relight Epoch: [96] [   7/  30] time: 1424.4767, loss: 0.165919
# Relight Epoch: [96] [   8/  30] time: 1425.0222, loss: 0.181602
# Relight Epoch: [96] [   9/  30] time: 1425.6314, loss: 0.198795
# Relight Epoch: [96] [  10/  30] time: 1426.2190, loss: 0.193237
# Relight Epoch: [96] [  11/  30] time: 1426.7303, loss: 0.178108
# Relight Epoch: [96] [  12/  30] time: 1427.2091, loss: 0.181167
# Relight Epoch: [96] [  13/  30] time: 1427.6960, loss: 0.155635
# Relight Epoch: [96] [  14/  30] time: 1428.1604, loss: 0.139029
# Relight Epoch: [96] [  15/  30] time: 1428.6394, loss: 0.134512
# Relight Epoch: [96] [  16/  30] time: 1429.1311, loss: 0.148092
# Relight Epoch: [96] [  17/  30] time: 1429.6046, loss: 0.149962
# Relight Epoch: [96] [  18/  30] time: 1430.1011, loss: 0.109560
# Relight Epoch: [96] [  19/  30] time: 1430.5800, loss: 0.120714
# Relight Epoch: [96] [  20/  30] time: 1431.0716, loss: 0.137845
# Relight Epoch: [96] [  21/  30] time: 1431.5522, loss: 0.147494
# Relight Epoch: [96] [  22/  30] time: 1432.0376, loss: 0.104586
# Relight Epoch: [96] [  23/  30] time: 1432.5089, loss: 0.094581
# Relight Epoch: [96] [  24/  30] time: 1432.9902, loss: 0.138147
# Relight Epoch: [96] [  25/  30] time: 1433.4681, loss: 0.171584
# Relight Epoch: [96] [  26/  30] time: 1433.9671, loss: 0.154199
# Relight Epoch: [96] [  27/  30] time: 1434.4478, loss: 0.119481
# Relight Epoch: [96] [  28/  30] time: 1434.9463, loss: 0.116169
# Relight Epoch: [96] [  29/  30] time: 1435.4337, loss: 0.138534
# Relight Epoch: [96] [  30/  30] time: 1435.9253, loss: 0.151588
# Relight Epoch: [97] [   1/  30] time: 1436.3774, loss: 0.195982
# Relight Epoch: [97] [   2/  30] time: 1436.9619, loss: 0.157245
# Relight Epoch: [97] [   3/  30] time: 1437.5206, loss: 0.159365
# Relight Epoch: [97] [   4/  30] time: 1438.0739, loss: 0.157016
# Relight Epoch: [97] [   5/  30] time: 1438.6381, loss: 0.182022
# Relight Epoch: [97] [   6/  30] time: 1439.2162, loss: 0.172364
# Relight Epoch: [97] [   7/  30] time: 1439.8066, loss: 0.141053
# Relight Epoch: [97] [   8/  30] time: 1440.2853, loss: 0.178422
# Relight Epoch: [97] [   9/  30] time: 1440.7602, loss: 0.190640
# Relight Epoch: [97] [  10/  30] time: 1441.2389, loss: 0.181865
# Relight Epoch: [97] [  11/  30] time: 1441.7260, loss: 0.167221
# Relight Epoch: [97] [  12/  30] time: 1442.2022, loss: 0.196369
# Relight Epoch: [97] [  13/  30] time: 1442.6850, loss: 0.159465
# Relight Epoch: [97] [  14/  30] time: 1443.1711, loss: 0.193518
# Relight Epoch: [97] [  15/  30] time: 1443.6527, loss: 0.133104
# Relight Epoch: [97] [  16/  30] time: 1444.1286, loss: 0.158032
# Relight Epoch: [97] [  17/  30] time: 1444.5954, loss: 0.115786
# Relight Epoch: [97] [  18/  30] time: 1445.0864, loss: 0.137582
# Relight Epoch: [97] [  19/  30] time: 1445.5571, loss: 0.124185
# Relight Epoch: [97] [  20/  30] time: 1446.0573, loss: 0.137503
# Relight Epoch: [97] [  21/  30] time: 1446.5245, loss: 0.152146
# Relight Epoch: [97] [  22/  30] time: 1447.0072, loss: 0.109823
# Relight Epoch: [97] [  23/  30] time: 1447.4761, loss: 0.106719
# Relight Epoch: [97] [  24/  30] time: 1447.9485, loss: 0.089472
# Relight Epoch: [97] [  25/  30] time: 1448.4068, loss: 0.138000
# Relight Epoch: [97] [  26/  30] time: 1448.8833, loss: 0.178856
# Relight Epoch: [97] [  27/  30] time: 1449.3399, loss: 0.119411
# Relight Epoch: [97] [  28/  30] time: 1449.8078, loss: 0.119904
# Relight Epoch: [97] [  29/  30] time: 1450.3702, loss: 0.122320
# Relight Epoch: [97] [  30/  30] time: 1450.9259, loss: 0.153135
# Relight Epoch: [98] [   1/  30] time: 1451.4774, loss: 0.183216
# Relight Epoch: [98] [   2/  30] time: 1452.0184, loss: 0.145468
# Relight Epoch: [98] [   3/  30] time: 1452.5896, loss: 0.178952
# Relight Epoch: [98] [   4/  30] time: 1453.1601, loss: 0.145619
# Relight Epoch: [98] [   5/  30] time: 1453.7211, loss: 0.161074
# Relight Epoch: [98] [   6/  30] time: 1454.1809, loss: 0.140594
# Relight Epoch: [98] [   7/  30] time: 1454.6615, loss: 0.164030
# Relight Epoch: [98] [   8/  30] time: 1455.1327, loss: 0.163097
# Relight Epoch: [98] [   9/  30] time: 1455.6213, loss: 0.216623
# Relight Epoch: [98] [  10/  30] time: 1456.0880, loss: 0.184678
# Relight Epoch: [98] [  11/  30] time: 1456.5778, loss: 0.197296
# Relight Epoch: [98] [  12/  30] time: 1457.0371, loss: 0.170526
# Relight Epoch: [98] [  13/  30] time: 1457.5224, loss: 0.164100
# Relight Epoch: [98] [  14/  30] time: 1457.9835, loss: 0.151394
# Relight Epoch: [98] [  15/  30] time: 1458.4781, loss: 0.153275
# Relight Epoch: [98] [  16/  30] time: 1458.9482, loss: 0.136876
# Relight Epoch: [98] [  17/  30] time: 1459.4189, loss: 0.148982
# Relight Epoch: [98] [  18/  30] time: 1459.9091, loss: 0.111207
# Relight Epoch: [98] [  19/  30] time: 1460.3812, loss: 0.128699
# Relight Epoch: [98] [  20/  30] time: 1460.8650, loss: 0.114712
# Relight Epoch: [98] [  21/  30] time: 1461.3307, loss: 0.146246
# Relight Epoch: [98] [  22/  30] time: 1461.8066, loss: 0.109444
# Relight Epoch: [98] [  23/  30] time: 1462.2814, loss: 0.113074
# Relight Epoch: [98] [  24/  30] time: 1462.7638, loss: 0.103065
# Relight Epoch: [98] [  25/  30] time: 1463.2189, loss: 0.146346
# Relight Epoch: [98] [  26/  30] time: 1463.7485, loss: 0.203017
# Relight Epoch: [98] [  27/  30] time: 1464.3072, loss: 0.143343
# Relight Epoch: [98] [  28/  30] time: 1464.9009, loss: 0.140212
# Relight Epoch: [98] [  29/  30] time: 1465.4632, loss: 0.110530
# Relight Epoch: [98] [  30/  30] time: 1466.0491, loss: 0.172141
# Relight Epoch: [99] [   1/  30] time: 1466.6229, loss: 0.157973
# Relight Epoch: [99] [   2/  30] time: 1467.1891, loss: 0.200141
# Relight Epoch: [99] [   3/  30] time: 1467.6687, loss: 0.159959
# Relight Epoch: [99] [   4/  30] time: 1468.1352, loss: 0.152016
# Relight Epoch: [99] [   5/  30] time: 1468.6110, loss: 0.141076
# Relight Epoch: [99] [   6/  30] time: 1469.0882, loss: 0.165417
# Relight Epoch: [99] [   7/  30] time: 1469.5664, loss: 0.156517
# Relight Epoch: [99] [   8/  30] time: 1470.0435, loss: 0.159304
# Relight Epoch: [99] [   9/  30] time: 1470.5339, loss: 0.183435
# Relight Epoch: [99] [  10/  30] time: 1471.0090, loss: 0.189507
# Relight Epoch: [99] [  11/  30] time: 1471.4910, loss: 0.174376
# Relight Epoch: [99] [  12/  30] time: 1471.9588, loss: 0.165662
# Relight Epoch: [99] [  13/  30] time: 1472.4548, loss: 0.173953
# Relight Epoch: [99] [  14/  30] time: 1472.9155, loss: 0.188863
# Relight Epoch: [99] [  15/  30] time: 1473.4037, loss: 0.153205
# Relight Epoch: [99] [  16/  30] time: 1473.8739, loss: 0.142524
# Relight Epoch: [99] [  17/  30] time: 1474.3688, loss: 0.150150
# Relight Epoch: [99] [  18/  30] time: 1474.8327, loss: 0.123521
# Relight Epoch: [99] [  19/  30] time: 1475.3033, loss: 0.111805
# Relight Epoch: [99] [  20/  30] time: 1475.7828, loss: 0.141804
# Relight Epoch: [99] [  21/  30] time: 1476.2545, loss: 0.143789
# Relight Epoch: [99] [  22/  30] time: 1476.7405, loss: 0.120110
# Relight Epoch: [99] [  23/  30] time: 1477.2315, loss: 0.114557
# Relight Epoch: [99] [  24/  30] time: 1477.8091, loss: 0.094198
# Relight Epoch: [99] [  25/  30] time: 1478.3686, loss: 0.141401
# Relight Epoch: [99] [  26/  30] time: 1478.9578, loss: 0.183895
# Relight Epoch: [99] [  27/  30] time: 1479.5147, loss: 0.154517
# Relight Epoch: [99] [  28/  30] time: 1480.1050, loss: 0.120210
# Relight Epoch: [99] [  29/  30] time: 1480.6863, loss: 0.110368
# Relight Epoch: [99] [  30/  30] time: 1481.1790, loss: 0.146200
# Relight Epoch: [100] [   1/  30] time: 1481.6610, loss: 0.156408
# Relight Epoch: [100] [   2/  30] time: 1482.1355, loss: 0.196803
# Relight Epoch: [100] [   3/  30] time: 1482.6044, loss: 0.152496
# Relight Epoch: [100] [   4/  30] time: 1483.0867, loss: 0.160780
# Relight Epoch: [100] [   5/  30] time: 1483.5565, loss: 0.151662
# Relight Epoch: [100] [   6/  30] time: 1484.0191, loss: 0.142529
# Relight Epoch: [100] [   7/  30] time: 1484.5086, loss: 0.173303
# Relight Epoch: [100] [   8/  30] time: 1484.9665, loss: 0.149012
# Relight Epoch: [100] [   9/  30] time: 1485.4581, loss: 0.188620
# Relight Epoch: [100] [  10/  30] time: 1485.9152, loss: 0.195686
# Relight Epoch: [100] [  11/  30] time: 1486.4019, loss: 0.164931
# Relight Epoch: [100] [  12/  30] time: 1486.8562, loss: 0.179129
# Relight Epoch: [100] [  13/  30] time: 1487.3378, loss: 0.169711
# Relight Epoch: [100] [  14/  30] time: 1487.8040, loss: 0.150108
# Relight Epoch: [100] [  15/  30] time: 1488.2836, loss: 0.166455
# Relight Epoch: [100] [  16/  30] time: 1488.7596, loss: 0.126542
# Relight Epoch: [100] [  17/  30] time: 1489.2487, loss: 0.148319
# Relight Epoch: [100] [  18/  30] time: 1489.7170, loss: 0.139645
# Relight Epoch: [100] [  19/  30] time: 1490.1950, loss: 0.143228
# Relight Epoch: [100] [  20/  30] time: 1490.6786, loss: 0.130662
# Relight Epoch: [100] [  21/  30] time: 1491.2562, loss: 0.169353
# Relight Epoch: [100] [  22/  30] time: 1491.8102, loss: 0.171615
# Relight Epoch: [100] [  23/  30] time: 1492.3633, loss: 0.100415
# Relight Epoch: [100] [  24/  30] time: 1492.9459, loss: 0.111367
# Relight Epoch: [100] [  25/  30] time: 1493.5156, loss: 0.106238
# Relight Epoch: [100] [  26/  30] time: 1494.1068, loss: 0.157378
# Relight Epoch: [100] [  27/  30] time: 1494.5773, loss: 0.192688
# Relight Epoch: [100] [  28/  30] time: 1495.0738, loss: 0.123361
# Relight Epoch: [100] [  29/  30] time: 1495.5516, loss: 0.149882
# Relight Epoch: [100] [  30/  30] time: 1496.0652, loss: 0.120391
# Evaluating for phase Relight / epoch 100...
# Finished training for phase Relight.

# %%
import os
from glob import glob
import numpy as np
import torch


data_dir = '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/eval/low'  # Directory storing the test data
ckpt_dir = '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/checkpoints'  # Directory for checkpoints
res_dir = '/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/eval/enhanced'  # Directory for saving the results



# Create directories for saving the results
if not os.path.exists(res_dir):
    os.makedirs(res_dir)



# Initialize the model
model = RetinexNet().to(device)

# Load the trained weights into the model
# Assuming you have two separate model checkpoints for different phases
decom_ckpt_path = os.path.join(ckpt_dir, 'decom.pth')
relight_ckpt_path = os.path.join(ckpt_dir, 'relight.pth')
if os.path.exists(decom_ckpt_path) and os.path.exists(relight_ckpt_path):
    model.load_state_dict(torch.load(decom_ckpt_path, map_location=device))
else:
    print("Checkpoint not found.")

def predict(model):
    test_low_data_names = glob('/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/eval/low/*.png')
    test_low_data_names.sort()
    print('Number of evaluation images: %d' % len(test_low_data_names))

    # Assuming predict function is implemented within the model
    model.predict(test_low_data_names, res_dir=res_dir, ckpt_dir=ckpt_dir)

# Run the prediction
predict(model)
# Out:
# Number of evaluation images: 15
# Decom   : Model restore success!
# Relight : Model restore success!
# Processing  1.png
# 1.png
# Processing  111.png
# 111.png
# Processing  146.png
# 146.png
# Processing  179.png
# 179.png
# Processing  22.png
# 22.png
# Processing  23.png
# 23.png
# Processing  493.png
# 493.png
# Processing  547.png
# 547.png
# Processing  55.png
# 55.png
# Processing  665.png
# 665.png
# Processing  669.png
# 669.png
# Processing  748.png
# 748.png
# Processing  778.png
# 778.png
# Processing  780.png
# 780.png
# Processing  79.png
# 79.png

# %%
import cv2
def compare_psnr(img1, img2, maxvalue):
  img1, img2 = img1.astype(np.float64), img2.astype(np.float64)
  mse = np.mean((img1 - img2) ** 2)
  return 10 * np.log10((maxvalue ** 2) / mse)

def compare_images_in_folders(folder1, folder2, maxvalue):
    psnr_values = []
    for filename1 in os.listdir(folder1):
        if filename1.endswith(('.jpg', '.png', '.jpeg')):
            filename2 = os.path.join(folder2, filename1)
            if os.path.exists(filename2):
                img1 = cv2.imread(os.path.join(folder1, filename1))
                img2 = cv2.imread(filename2)
                if img1 is not None and img2 is not None:
                    psnr = compare_psnr(img1, img2, maxvalue)
                    psnr_values.append(psnr)
                else:
                    print(f"Could not read images: {filename1}, {filename2}")
            else:
                print(f"File not found: {filename2}")
    if psnr_values:
        avg_psnr = np.mean(psnr_values)
        print(f"Average PSNR: {avg_psnr:.2f} dB")
    else:
        print("No valid image pairs found for comparison.")

folder1 = "/content/drive/MyDrive/Colab Notebooks/RetinexNet_self_do/eval/enhanced"
folder2 = "/content/drive/MyDrive/Colab Notebooks/Zero_DCE_self_do/data/test_data/high"
maxvalue = 255  # Assuming 8-bit images
compare_images_in_folders(folder1, folder2, maxvalue)
